# %%
import time
import math
import numpy as np
import tensorly as tl
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from brokenaxes import brokenaxes
from online_tensor_decomposition import *

# %%
# for sample video
from cv2 import VideoWriter, VideoWriter_fourcc, imshow

def make_video(tensor, filename, isColor=True):
    start = time.time()
    height = tensor.shape[1]
    width = tensor.shape[2]
    FPS = 24

    fourcc = VideoWriter_fourcc(*'MP42')
    video = VideoWriter(filename, fourcc, float(FPS), (width, height), isColor)

    for frame in tensor:
        video.write(np.uint8(frame))
    video.release()
    print('created', filename, time.time()-start)

# %%
results = {}

# %% [markdown]
# ### Plot Results

# %%
def plot(datasets, name):
    def plotLocal(min_val=1, max_val=1e4):
        points  = []
        for dataset in datasets:
            if dataset in results:
                for lib in libs:
                    if lib in results[dataset]:
                        point = [lib, dataset, [results[dataset][lib][3]], [results[dataset][lib][1]]]
                        points.append(point)


#         print(points)

        if max_val > 1e+3: ### For brokenaxes
            bax = brokenaxes(xlims=((min_val, 2e4),(20000, 2e5)), d = 0,
                             wspace=0.05,  xscale='log',)
            for point in points :
                lib, data, x, y = point
                if len(x) != 0:
                    if x[0] < 1e+3 + 5000:
                        bax.plot(x, y, label=lib, 
                                 c= dct[lib],  marker=dct1[data],
                                    mfc='none', ms = 10, mew = 1.8)
                    else:
                        x = 50000 
                        bax.plot(x, y, label=lib, 
                                 c= dct[lib],  marker=dct1[data], 
                                mfc='none', ms = 10, mew = 1.8)
        else:  
            bax = brokenaxes(xscale='log')
#             bax = brokenaxes(xscale='log', subplot_spec=sps1)
            for point in points :
                lib, data, x, y = point
                if len(x) != 0:
                    if x[0] != 0 and y[0] != 0:
                        bax.plot(x, y, label=lib,
                                 c= dct[lib],  marker=dct1[data],
                                mfc='none', ms = 10, mew = 1.8)
#         bax.set_ylim([0.97,0.99])
#         bax.set_yscale('log') 
#         bax.set_xscale('log')


#         bax.tick_params(axis = 'y', labelsize =8)
        bax.set_ylabel('Average of Local Fitness', size = 10, labelpad=50)
        bax.set_xlabel('Average of Local Running Time (s)', size = 10, labelpad=25)  ### Labelpad > space btw xaxis and xlabel
        plt.subplots_adjust(hspace=0.1, bottom = 0.4 , left = 0.23, top = 0.9) ### Plot to remove whitespace of plot 
#         plt.show()
        plt.savefig(f'./plots/{name}_local.pdf',bbox_inches = 'tight', pad_inches = 0)

    def plotGlobal(min_val=1, max_val=1e4):
        points  = []
        for dataset in datasets:
            if dataset in results:
                for lib in libs:
                    if lib in results[dataset]:
                        point = [lib, dataset, [results[dataset][lib][2]], [results[dataset][lib][0]]]
                        points.append(point)


#         print(points)

        if max_val > 1e+3: ### For brokenaxes
            bax = brokenaxes(xlims=((min_val, 2e4),(20000, 2e5)), d = 0,
                             wspace=0.05,  xscale='log',)
            for point in points :
                lib, data, x, y = point
                if len(x) != 0:
                    if x[0] < 1e+3 + 5000:
                        bax.plot(x, y, label=lib, 
                                 c= dct[lib],  marker=dct1[data],
                                    mfc='none', ms = 10, mew = 1.8)
                    else:
                        x = 50000 
                        bax.plot(x, y, label=lib, 
                                 c= dct[lib],  marker=dct1[data], 
                                mfc='none', ms = 10, mew = 1.8)
        else:  
            bax = brokenaxes(xscale='log')
#             bax = brokenaxes(xscale='log', subplot_spec=sps2)
            for point in points :
                lib, data, x, y = point
                if len(x) != 0:
                    if x[0] != 0 and y[0] != 0:
                        bax.plot(x, y, label=lib,
                                 c= dct[lib],  marker=dct1[data],
                                mfc='none', ms = 10, mew = 1.8)

#         bax.set_ylim([0.97,0.99])
#         bax.set_xscale('log') 
        bax.set_ylabel('Global Fitness', size = 10, labelpad=50)
        bax.set_xlabel('Global Running Time (s)', size = 10, labelpad=25)  ### Labelpad > space btw xaxis and xlabel
        plt.subplots_adjust(hspace=0.1, bottom = 0.4 , left = 0.23, top = 0.9) ### Plot to remove whitespace of plot 
#         plt.show()
        plt.savefig(f'./plots/{name}_global.pdf',bbox_inches = 'tight', pad_inches = 0)

    markers = ("o", "x", "s", "^", "4")
    colors = ('dodgerblue','mediumseagreen', 'hotpink', '#fba84a')

    libs = ("dao", "ocp", "dtd", "fcp")
    f = lambda m,c: plt.plot([],[], color=c, marker = m,
                             mfc='none', ms = 10, mew = 1.8,
                                ls="none")[0]
    f2 = lambda c: plt.plot([],[],marker='.', color=c, )[0]

    dct = {}
    dct1 = {}

    for color, lib in zip(colors, libs):
        dct[lib] = color

    for data, marker in zip(datasets, markers):
        dct1[data] = marker
    
    fig = plt.figure(figsize = (4, 4), dpi = 150,)   ### figsize = (row, col), dpi > resolution(?)
#     sps1, sps2 = GridSpec(1,2)
    plotLocal(max_val=100)
    fig = plt.figure(figsize = (4, 4), dpi = 150,)   ### figsize = (row, col), dpi > resolution(?)
    plotGlobal(max_val=100)

# %% [markdown]
# ---
# ### Synthetic Data

# %%
import csv
synthetic_data = tl.tensor(np.zeros([1000, 10, 20, 30], dtype='f'))

for i in range(200):
    start = time.time()
    with open('../Data/synthetic_data/data_normal/data{}.tensor'.format(i)) as file:
        reader = csv.reader(file, delimiter='\t')    
        for row in reader:
            indices = [[index] for index in np.int64(np.asarray(row[:-1]))-1]
            synthetic_data[tuple(indices)] = np.double(row[-1])
    print('>> synthetic_data{} loaded '.format(i), time.time() - start)
# Out:
# >> synthetic_data0 loaded  0.7164537906646729
# >> synthetic_data1 loaded  0.6905031204223633
# >> synthetic_data2 loaded  0.7511835098266602
# >> synthetic_data3 loaded  0.7146596908569336
# >> synthetic_data4 loaded  0.6826651096343994
# >> synthetic_data5 loaded  0.6960198879241943
# >> synthetic_data6 loaded  0.7566258907318115
# >> synthetic_data7 loaded  0.7077476978302002
# >> synthetic_data8 loaded  0.7294819355010986
# >> synthetic_data9 loaded  0.7063572406768799
# >> synthetic_data10 loaded  0.6619734764099121
# >> synthetic_data11 loaded  0.6738255023956299
# >> synthetic_data12 loaded  0.6857893466949463
# >> synthetic_data13 loaded  0.7101683616638184
# >> synthetic_data14 loaded  0.667212724685669
# >> synthetic_data15 loaded  0.683753490447998
# >> synthetic_data16 loaded  0.6936306953430176
# >> synthetic_data17 loaded  0.6866610050201416
# >> synthetic_data18 loaded  0.7423434257507324
# >> synthetic_data19 loaded  0.6791784763336182
# >> synthetic_data20 loaded  0.7021112442016602
# >> synthetic_data21 loaded  0.6879942417144775
# >> synthetic_data22 loaded  0.6907143592834473
# >> synthetic_data23 loaded  0.6982579231262207
# >> synthetic_data24 loaded  0.6971616744995117
# >> synthetic_data25 loaded  0.7009427547454834
# >> synthetic_data26 loaded  0.688382625579834
# >> synthetic_data27 loaded  0.6908676624298096
# >> synthetic_data28 loaded  0.6858139038085938
# >> synthetic_data29 loaded  0.6944797039031982
# >> synthetic_data30 loaded  0.7029478549957275
# >> synthetic_data31 loaded  0.6897375583648682
# >> synthetic_data32 loaded  0.6883082389831543
# >> synthetic_data33 loaded  0.7021996974945068
# >> synthetic_data34 loaded  0.6973724365234375
# >> synthetic_data35 loaded  0.7014784812927246
# >> synthetic_data36 loaded  0.6942663192749023
# >> synthetic_data37 loaded  0.7041983604431152
# >> synthetic_data38 loaded  0.7040090560913086
# >> synthetic_data39 loaded  0.7099907398223877
# >> synthetic_data40 loaded  0.6943097114562988
# >> synthetic_data41 loaded  0.6887903213500977
# >> synthetic_data42 loaded  0.6929256916046143
# >> synthetic_data43 loaded  0.7001080513000488
# >> synthetic_data44 loaded  0.6968429088592529
# >> synthetic_data45 loaded  0.6992232799530029
# >> synthetic_data46 loaded  0.73929762840271
# >> synthetic_data47 loaded  0.7839593887329102
# >> synthetic_data48 loaded  0.6956014633178711
# >> synthetic_data49 loaded  0.6948482990264893
# >> synthetic_data50 loaded  0.6832602024078369
# >> synthetic_data51 loaded  0.697866678237915
# >> synthetic_data52 loaded  0.7061469554901123
# >> synthetic_data53 loaded  0.7028615474700928
# >> synthetic_data54 loaded  0.7160460948944092
# >> synthetic_data55 loaded  0.6940708160400391
# >> synthetic_data56 loaded  0.8949275016784668
# >> synthetic_data57 loaded  0.7159640789031982
# >> synthetic_data58 loaded  0.7159316539764404
# >> synthetic_data59 loaded  0.7071590423583984
# >> synthetic_data60 loaded  0.6986894607543945
# >> synthetic_data61 loaded  0.7072269916534424
# >> synthetic_data62 loaded  0.7123043537139893
# >> synthetic_data63 loaded  0.6969907283782959
# >> synthetic_data64 loaded  0.7104983329772949
# >> synthetic_data65 loaded  0.7059817314147949
# >> synthetic_data66 loaded  0.7015502452850342
# >> synthetic_data67 loaded  0.7110261917114258
# >> synthetic_data68 loaded  0.7036044597625732
# >> synthetic_data69 loaded  0.6849586963653564
# >> synthetic_data70 loaded  0.7004666328430176
# >> synthetic_data71 loaded  0.6968138217926025
# >> synthetic_data72 loaded  0.6980934143066406
# >> synthetic_data73 loaded  0.6951858997344971
# >> synthetic_data74 loaded  0.7031815052032471
# >> synthetic_data75 loaded  0.6948397159576416
# >> synthetic_data76 loaded  0.6906921863555908
# >> synthetic_data77 loaded  0.7078187465667725
# >> synthetic_data78 loaded  0.6812336444854736
# >> synthetic_data79 loaded  0.692690372467041
# >> synthetic_data80 loaded  0.7209591865539551
# >> synthetic_data81 loaded  0.6965835094451904
# >> synthetic_data82 loaded  0.86014723777771
# >> synthetic_data83 loaded  0.9757530689239502
# >> synthetic_data84 loaded  0.7329211235046387
# >> synthetic_data85 loaded  0.6924011707305908
# >> synthetic_data86 loaded  0.7085983753204346
# >> synthetic_data87 loaded  1.1738002300262451
# >> synthetic_data88 loaded  0.7044968605041504
# >> synthetic_data89 loaded  0.6922321319580078
# >> synthetic_data90 loaded  0.6919376850128174
# >> synthetic_data91 loaded  0.7070481777191162
# >> synthetic_data92 loaded  0.7045445442199707
# >> synthetic_data93 loaded  0.7077243328094482
# >> synthetic_data94 loaded  0.7109208106994629
# >> synthetic_data95 loaded  0.691821813583374
# >> synthetic_data96 loaded  0.7023885250091553
# >> synthetic_data97 loaded  0.9343607425689697
# >> synthetic_data98 loaded  1.0786066055297852
# >> synthetic_data99 loaded  0.8858156204223633
# >> synthetic_data100 loaded  0.696552038192749
# >> synthetic_data101 loaded  0.6994643211364746
# >> synthetic_data102 loaded  0.6956641674041748
# >> synthetic_data103 loaded  0.7086303234100342
# >> synthetic_data104 loaded  0.7214713096618652
# >> synthetic_data105 loaded  0.7371172904968262
# >> synthetic_data106 loaded  0.7062897682189941
# >> synthetic_data107 loaded  0.6990582942962646
# >> synthetic_data108 loaded  0.7037534713745117
# >> synthetic_data109 loaded  0.7028083801269531
# >> synthetic_data110 loaded  0.716439962387085
# >> synthetic_data111 loaded  0.6980383396148682
# >> synthetic_data112 loaded  0.7442011833190918
# >> synthetic_data113 loaded  0.7152256965637207
# >> synthetic_data114 loaded  0.7021901607513428
# >> synthetic_data115 loaded  0.6948714256286621
# >> synthetic_data116 loaded  0.7041378021240234
# >> synthetic_data117 loaded  0.7000303268432617
# >> synthetic_data118 loaded  0.6969974040985107
# >> synthetic_data119 loaded  0.6993982791900635
# >> synthetic_data120 loaded  0.6946070194244385
# >> synthetic_data121 loaded  0.6914186477661133
# >> synthetic_data122 loaded  0.7016394138336182
# >> synthetic_data123 loaded  0.6883687973022461
# >> synthetic_data124 loaded  0.6950502395629883
# >> synthetic_data125 loaded  0.6915073394775391
# >> synthetic_data126 loaded  0.6988906860351562
# >> synthetic_data127 loaded  0.6991569995880127
# >> synthetic_data128 loaded  0.6984241008758545
# >> synthetic_data129 loaded  0.6917414665222168
# >> synthetic_data130 loaded  0.6953747272491455
# >> synthetic_data131 loaded  0.6917719841003418
# >> synthetic_data132 loaded  0.6901419162750244
# >> synthetic_data133 loaded  0.6901731491088867
# >> synthetic_data134 loaded  0.6925735473632812
# >> synthetic_data135 loaded  0.6835000514984131
# >> synthetic_data136 loaded  0.6908860206604004
# >> synthetic_data137 loaded  0.7252788543701172
# >> synthetic_data138 loaded  0.6969394683837891
# >> synthetic_data139 loaded  0.6936495304107666
# >> synthetic_data140 loaded  0.7063760757446289
# >> synthetic_data141 loaded  0.7018728256225586
# >> synthetic_data142 loaded  0.6915864944458008
# >> synthetic_data143 loaded  0.7092201709747314
# >> synthetic_data144 loaded  0.7107105255126953
# >> synthetic_data145 loaded  0.7046065330505371
# >> synthetic_data146 loaded  0.71040940284729
# >> synthetic_data147 loaded  0.7092938423156738
# >> synthetic_data148 loaded  0.7070579528808594
# >> synthetic_data149 loaded  0.6848797798156738
# >> synthetic_data150 loaded  0.6812975406646729
# >> synthetic_data151 loaded  0.6898946762084961
# >> synthetic_data152 loaded  0.6899130344390869
# >> synthetic_data153 loaded  0.6805689334869385
# >> synthetic_data154 loaded  0.6911334991455078
# >> synthetic_data155 loaded  0.6842193603515625
# >> synthetic_data156 loaded  0.6799376010894775
# >> synthetic_data157 loaded  0.6845657825469971
# >> synthetic_data158 loaded  0.6845500469207764
# >> synthetic_data159 loaded  0.7037100791931152
# >> synthetic_data160 loaded  0.7028763294219971
# >> synthetic_data161 loaded  0.703803539276123
# >> synthetic_data162 loaded  0.7010922431945801
# >> synthetic_data163 loaded  0.6932721138000488
# >> synthetic_data164 loaded  0.7014756202697754
# >> synthetic_data165 loaded  0.7015163898468018
# >> synthetic_data166 loaded  0.7046539783477783
# >> synthetic_data167 loaded  0.6985659599304199
# >> synthetic_data168 loaded  0.7046597003936768
# >> synthetic_data169 loaded  0.8191981315612793
# >> synthetic_data170 loaded  0.8030245304107666
# >> synthetic_data171 loaded  0.8654966354370117
# >> synthetic_data172 loaded  0.8266441822052002
# >> synthetic_data173 loaded  0.8234930038452148
# >> synthetic_data174 loaded  0.9565391540527344
# >> synthetic_data175 loaded  0.766484260559082
# >> synthetic_data176 loaded  0.68729567527771
# >> synthetic_data177 loaded  0.6911015510559082
# >> synthetic_data178 loaded  0.6882553100585938
# >> synthetic_data179 loaded  0.6946823596954346
# >> synthetic_data180 loaded  0.6742613315582275
# >> synthetic_data181 loaded  0.6886258125305176
# >> synthetic_data182 loaded  0.6986491680145264
# >> synthetic_data183 loaded  0.8021409511566162
# >> synthetic_data184 loaded  0.842749834060669
# >> synthetic_data185 loaded  0.691598653793335
# >> synthetic_data186 loaded  0.727996826171875
# >> synthetic_data187 loaded  0.702610969543457
# >> synthetic_data188 loaded  0.6996402740478516
# >> synthetic_data189 loaded  0.692664623260498
# >> synthetic_data190 loaded  0.6852521896362305
# >> synthetic_data191 loaded  0.6823444366455078
# >> synthetic_data192 loaded  0.7459993362426758
# >> synthetic_data193 loaded  0.8215506076812744
# >> synthetic_data194 loaded  0.696570873260498
# >> synthetic_data195 loaded  0.6924593448638916
# >> synthetic_data196 loaded  0.6912732124328613
# >> synthetic_data197 loaded  0.6904933452606201
# >> synthetic_data198 loaded  0.6918978691101074
# >> synthetic_data199 loaded  0.6827826499938965

# %%
n_iter = 1
ul = 1.2
ll = 1.1

# %%
tensor_stream = create_tensor_stream(synthetic_data, start_to_stream=10, batch_sizes=np.full((99), 10, dtype=int))

results['synthetic20'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['synthetic30'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['synthetic40'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=40, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# results['synthetic50'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# results['synthetic100'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=100, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# results['synthetic150'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=150, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# results['synthetic200'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=200, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# results['synthetic30'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# results['synthetic40'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=40, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 4.7295451164245605
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 193629.38400656843
# split: 4 refine: 0
# global fitness 0.21162354499771263
# local fitness 0.21158890170407885
# global running time 21.50312042236328
# local running time 0.049851395867087624
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 235312.4209718818
# global fitness 0.04190795619364818
# local fitness 0.04322455991460661
# global running time 9.887385845184326
# local running time 0.04987637442771835
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 235329.77224621898
# global fitness 0.041837309188174854
# local fitness 0.0432223169189091
# global running time 5.815694570541382
# local running time 0.008673289809564147
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.08113477288491278
# global running time 36.07176899909973
# -----------------------------------
# making init decomposition result: 4.382638216018677
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 168968.07886471378
# split: 4 refine: 0
# global fitness 0.31203388521139375
# local fitness 0.31192500534036205
# global running time 27.009010076522827
# local running time 0.07005322099936129
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 231131.1913870024
# global fitness 0.058932143790950575
# local fitness 0.06359514808597344
# global running time 10.924588441848755
# local running time 0.06409202199993712
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 231173.0388295508
# global fitness 0.05876175881257295
# local fitness 0.06360846127154529
# global running time 5.66614842414856
# local running time 0.010841314238731307
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.11426923131500544
# global running time 45.714433908462524
# -----------------------------------
# making init decomposition result: 5.203061103820801
#
#  >> dao rank-40 n_iter-1
# ||A-B||: 142816.98155290334
# split: 4 refine: 0
# global fitness 0.41851002517786495
# local fitness 0.41853614007428075
# global running time 31.797017335891724
# local running time 0.0831976779783615
#
#  >> dtd rank-40 n_iter-1
# ||A-B||: 227378.43928362656
# global fitness 0.07421175341704656
# local fitness 0.08412025248270139
# global running time 11.987452268600464
# local running time 0.0663044693494084
#
#  >> ocp rank-40 n_iter-1
# ||A-B||: 227450.63157200607
# global fitness 0.07391781713933165
# local fitness 0.08412383086235065
# global running time 6.338660717010498
# local running time 0.009300246383204605
#
#  >> fcp rank-40 n_iter-1
# global fitness 0.1480693835097614
# global running time 63.27186036109924

# %%
plot(('synthetic50', 'synthetic20', 'synthetic30', 'synthetic40', '_synthetic100'), 'synthetic')

# %% [markdown]
# ---
# ### Sample Video (done)

# %%
import csv
sample_video = tl.tensor(np.zeros([205, 240, 320, 3], dtype='d'))

for i in range(41):
    start = time.time()
    with open('../Data/sample_video/data/video{}.tensor'.format(i)) as file:
        reader = csv.reader(file, delimiter='\t')    
        for row in reader:
            indices = [[index] for index in np.int64(np.asarray(row[:-1]))-1]
            sample_video[tuple(indices)] = np.double(row[-1])
    print('>> sample_video{} loaded '.format(i), time.time() - start)
# Out:
# >> sample_video0 loaded  24.727651596069336
# >> sample_video1 loaded  25.82331132888794
# >> sample_video2 loaded  21.936811923980713
# >> sample_video3 loaded  21.411168336868286
# >> sample_video4 loaded  22.1275532245636
# >> sample_video5 loaded  21.544241428375244
# >> sample_video6 loaded  21.651058197021484
# >> sample_video7 loaded  22.26132369041443
# >> sample_video8 loaded  23.681866884231567
# >> sample_video9 loaded  25.961312294006348
# >> sample_video10 loaded  24.938040494918823
# >> sample_video11 loaded  22.538767099380493
# >> sample_video12 loaded  21.744826555252075
# >> sample_video13 loaded  21.46475601196289
# >> sample_video14 loaded  21.53390097618103
# >> sample_video15 loaded  21.9859459400177
# >> sample_video16 loaded  21.959258317947388
# >> sample_video17 loaded  26.04772162437439
# >> sample_video18 loaded  26.207767724990845
# >> sample_video19 loaded  22.182554721832275
# >> sample_video20 loaded  21.503894567489624
# >> sample_video21 loaded  21.51828098297119
# >> sample_video22 loaded  21.441502809524536
# >> sample_video23 loaded  21.371550798416138
# >> sample_video24 loaded  21.804105281829834
# >> sample_video25 loaded  23.352006912231445
# >> sample_video26 loaded  21.535264253616333
# >> sample_video27 loaded  21.488600730895996
# >> sample_video28 loaded  21.463197708129883
# >> sample_video29 loaded  21.387025117874146
# >> sample_video30 loaded  21.49476981163025
# >> sample_video31 loaded  21.303110599517822
# >> sample_video32 loaded  21.472527027130127
# >> sample_video33 loaded  21.35424566268921
# >> sample_video34 loaded  22.078946352005005
# >> sample_video35 loaded  22.113048553466797
# >> sample_video36 loaded  23.98655867576599
# >> sample_video37 loaded  22.45445442199707
# >> sample_video38 loaded  21.30923342704773
# >> sample_video39 loaded  21.420001745224
# >> sample_video40 loaded  21.36370015144348

# %%
(n_iter, ul, ll) = (1, 6, 2)

# %%
tensor_stream = create_tensor_stream(sample_video, start_to_stream=5, batch_sizes=np.full((40), 5, dtype=int))
results['video10'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video20'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video30'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video40'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=40, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video50'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 22.746444940567017
#
#  >> dao rank-10 n_iter-1
# ||A-B||: 146153.71216886237
# split: 3 refine: 8
# global fitness 0.8362607533501323
# local fitness 0.8520829815692748
# global running time 100.99605941772461
# local running time 0.43735945224761963
#
#  >> dtd rank-10 n_iter-1
# ||A-B||: 195313.4254300393
# global fitness 0.781186035811596
# local fitness 0.7800212481960113
# global running time 44.46780848503113
# local running time 0.3548704028129578
#
#  >> ocp rank-10 n_iter-1
# ||A-B||: 211738.46847801702
# global fitness 0.762784695640638
# local fitness 0.7846728552091085
# global running time 38.082536697387695
# local running time 0.19069707989692689
#
#  >> fcp rank-10 n_iter-1
# global fitness 0.8255977816419316
# global running time 437.7977395057678
# -----------------------------------
# making init decomposition result: 45.40920114517212
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 124158.6320478974
# split: 4 refine: 11
# global fitness 0.8609023296437898
# local fitness 0.8801053727460515
# global running time 250.07680225372314
# local running time 0.6729969024658203
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 163279.1573453879
# global fitness 0.8170747371338072
# local fitness 0.8150429714198305
# global running time 77.42964601516724
# local running time 0.6075900852680206
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 166053.16938260765
# global fitness 0.8139669498978097
# local fitness 0.8219156152115171
# global running time 66.95355439186096
# local running time 0.3467556297779083
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.8476646529906364
# global running time 877.6215732097626
# -----------------------------------
# making init decomposition result: 68.86998653411865
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 121844.96320294535
# split: 3 refine: 10
# global fitness 0.8634943841872421
# local fitness 0.8868192363977355
# global running time 316.1068389415741
# local running time 1.1986477613449096
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 148268.7563453826
# global fitness 0.8338912224298742
# local fitness 0.8296541938993308
# global running time 116.88767528533936
# local running time 1.0085930824279785
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 174072.47888950811
# global fitness 0.8049827395221273
# local fitness 0.8301543590473266
# global running time 96.8699860572815
# local running time 0.5116538524627685
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.8618757060286233
# global running time 1306.737553358078
# -----------------------------------
# making init decomposition result: 90.7510278224945
#
#  >> dao rank-40 n_iter-1
# ||A-B||: 99096.2998300206
# split: 4 refine: 10
# global fitness 0.8889802165188255
# local fitness 0.9030852893732852
# global running time 487.0205805301666
# local running time 1.5594968318939209
#
#  >> dtd rank-40 n_iter-1
# ||A-B||: 142216.4875033778
# global fitness 0.8406717135033227
# local fitness 0.8371701783971579
# global running time 146.9027283191681
# local running time 1.2118762254714965
#
#  >> ocp rank-40 n_iter-1
# ||A-B||: 150177.70152601972
# global fitness 0.831752588787697
# local fitness 0.8450400821021216
# global running time 123.432044506073
# local running time 0.6286132752895355
#
#  >> fcp rank-40 n_iter-1
# global fitness 0.8730912952556753
# global running time 1720.8283286094666
# -----------------------------------
# making init decomposition result: 108.53324007987976
#
#  >> dao rank-50 n_iter-1
# ||A-B||: 114471.6440980338
# split: 2 refine: 13
# global fitness 0.8717548771821269
# local fitness 0.8971503246870965
# global running time 409.33147859573364
# local running time 1.839246439933777
#
#  >> dtd rank-50 n_iter-1
# ||A-B||: 139212.78182472856
# global fitness 0.8440368316223323
# local fitness 0.8406545668328362
# global running time 170.98565244674683
# local running time 1.36874862909317
#
#  >> ocp rank-50 n_iter-1
# ||A-B||: 160981.82046200254
# global fitness 0.8196484946183373
# local fitness 0.8493485928337121
# global running time 147.5996220111847
# local running time 0.7848413765430451
#
#  >> fcp rank-50 n_iter-1
# global fitness 0.8807617739144357
# global running time 2181.8858976364136

# %%
plot(('video10', 'video20', 'video30', 'video40', 'video50'), 'video')

# %% [markdown]
# ---
# ### Stock

# %%
import pickle
with open('../Data/stock/index_data.pkl', 'rb') as f:
    index_data = pickle.load(f)

# %%
import csv

stock1_tensor = tl.tensor(np.zeros([855, 189, 5], dtype='d'))
start = time.time()
with open('../Data/stock/Stock_.tensor') as file:
    reader = csv.reader(file, delimiter='\t')    
    for row in reader:
        indices = np.asarray([index for index in np.int64(np.asarray(row[:-1]))])[[1, 0, 2]]
        stock1_tensor[tuple(indices)] = np.double(row[-1])
print('>> stock1_tensor loaded ', time.time() - start)
# Out:
# >> stock1_tensor loaded  12.76482081413269

# %%
(n_iter, ul, ll) = (1, 5, 3)

# %%
tensor_stream = create_tensor_stream(stock1_tensor, start_to_stream=5, batch_sizes=np.full((170), 5, dtype=int))
results['stock1-10'] = online_tensor_decomposition('stock1', stock1_tensor, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 0.41684913635253906
#
#  >> dao rank-10 n_iter-1
# ||A-B||: 16.197633679661045
# split: 15 refine: 4
# global fitness 0.9798601302225448
# local fitness 0.9768667822873673
# global running time 5.84090781211853
# local running time 0.0034936105503755458
#
#  >> dtd rank-10 n_iter-1
# ||A-B||: 17.81359810449565
# global fitness 0.9778508667878473
# local fitness 0.9736088470768431
# global running time 1.1587278842926025
# local running time 0.003824029249303481
#
#  >> ocp rank-10 n_iter-1
# ||A-B||: 18.021104492085353
# global fitness 0.9775928567780707
# local fitness 0.9736039503633721
# global running time 0.6601676940917969
# local running time 0.0010164190741146313
#
#  >> fcp rank-10 n_iter-1
# global fitness 0.9784827848239169
# global running time 5.165512323379517

# %%
plot(('stock1-10', 'stock1-10', 'stock1-10', 'stock1-10', 'stock1-10'), 'stock1')

# %%
import csv

stock2_tensor = tl.tensor(np.zeros([3089, 140, 5], dtype='d'))
start = time.time()
with open('../Data/stock/KOSPI140.tensor') as file:
    reader = csv.reader(file, delimiter='\t')    
    for row in reader:
        indices = np.asarray([index for index in np.int64(np.asarray(row[:-1]))])[[1, 0, 2]]
        stock2_tensor[tuple(indices)] = np.double(row[-1])
print('>> stock2_tensor loaded ', time.time() - start)
# Out:
# >> stock2_tensor loaded  33.025936126708984

# %%
(n_iter, ul, ll) = (1, 6, 5)

# %%
tensor_stream = create_tensor_stream(stock2_tensor, start_to_stream=5, batch_sizes=np.full((1028), 3, dtype=int))
results['stock2-10'] = online_tensor_decomposition('stock2', stock2_tensor, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock2-15'] = online_tensor_decomposition('stock2', stock2_tensor, tensor_stream, rank=15, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock2-20'] = online_tensor_decomposition('stock2', stock2_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock2-25'] = online_tensor_decomposition('stock2', stock2_tensor, tensor_stream, rank=25, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock2-30'] = online_tensor_decomposition('stock2', stock2_tensor, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# /home/lucetre/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# -----------------------------------
# making init decomposition result: 0.30512237548828125
#
#  >> dao rank-10 n_iter-1
# ||A-B||: 31.46381378207972
# split: 23 refine: 2
# global fitness 0.9760920640576836
# local fitness 0.971592335189096
# global running time 14.852266073226929
# local running time 0.004655557383823024
#
#  >> dtd rank-10 n_iter-1
# ||A-B||: 32.0875162143267
# global fitness 0.9756181406515604
# local fitness 0.9707014672341663
# global running time 6.00696873664856
# local running time 0.004242380073562206
#
#  >> ocp rank-10 n_iter-1
# ||A-B||: 32.22698147317051
# global fitness 0.9755121672785386
# local fitness 0.970709235083089
# global running time 3.094731569290161
# local running time 0.0014734803934505479
#
#  >> fcp rank-10 n_iter-1
# global fitness 0.9762125192062492
# global running time 24.105448722839355
# -----------------------------------
# making init decomposition result: 0.6657891273498535
#
#  >> dao rank-15 n_iter-1
# ||A-B||: 30.63607142079717
# split: 23 refine: 1
# global fitness 0.9767210282222744
# local fitness 0.9714979760649302
# global running time 11.598010540008545
# local running time 0.006957799776055006
#
#  >> dtd rank-15 n_iter-1
# ||A-B||: 31.270317622814154
# global fitness 0.9762390930800661
# local fitness 0.970539833038195
# global running time 8.977126121520996
# local running time 0.006838143335706065
#
#  >> ocp rank-15 n_iter-1
# ||A-B||: 31.38384334025314
# global fitness 0.9761528299970484
# local fitness 0.9705258693025798
# global running time 3.3864834308624268
# local running time 0.0014620692349593463
#
#  >> fcp rank-15 n_iter-1
# global fitness 0.9771607368976277
# global running time 36.82003331184387
# -----------------------------------
# making init decomposition result: 0.8417184352874756
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 29.91846851785092
# split: 23 refine: 1
# global fitness 0.9772663023697278
# local fitness 0.9713148587891165
# global running time 13.345194101333618
# local running time 0.008642381499249648
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 30.54025613881727
# global fitness 0.9767938339425133
# local fitness 0.9703447997864594
# global running time 11.029784202575684
# local running time 0.008713574956827126
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 30.79838987230602
# global fitness 0.9765976897367428
# local fitness 0.9703766075905126
# global running time 3.8218793869018555
# local running time 0.0017386164646668192
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.9778864651687664
# global running time 46.439560651779175
# -----------------------------------
# making init decomposition result: 0.1053776741027832
#
#  >> dao rank-25 n_iter-1
# ||A-B||: 28.992067829271594
# split: 23 refine: 1
# global fitness 0.9779702325567317
# local fitness 0.9710781453616786
# global running time 16.285908937454224
# local running time 0.011012947512971752
#
#  >> dtd rank-25 n_iter-1
# ||A-B||: 29.67299704277136
# global fitness 0.9774528250952472
# local fitness 0.970081964010296
# global running time 11.94504165649414
# local running time 0.01033000236355377
#
#  >> ocp rank-25 n_iter-1
# ||A-B||: 29.96360847955505
# global fitness 0.9772320025445275
# local fitness 0.9700558930227934
# global running time 3.2730422019958496
# local running time 0.0019494239458314176
#
#  >> fcp rank-25 n_iter-1
# global fitness 0.9784992001927394
# global running time 58.9672474861145
# -----------------------------------
# making init decomposition result: 0.11000323295593262
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 28.499908522866246
# split: 23 refine: 1
# global fitness 0.9783442022621351
# local fitness 0.9708847121900865
# global running time 22.11576771736145
# local running time 0.013335744926437793
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 29.167123570411317
# global fitness 0.9778372155781005
# local fitness 0.9699139902910968
# global running time 15.405244588851929
# local running time 0.013710584621948955
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 29.696517938687695
# global fitness 0.9774349526250893
# local fitness 0.9699647568781504
# global running time 3.718719244003296
# local running time 0.0023445234224490153
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.9790876197310916
# global running time 68.8602306842804

# %%
plot(('stock2-10', 'stock2-15', 'stock2-20', 'stock2-25', 'stock2-30'), 'stock2')

# %% [markdown]
# ---
# ### Air Quality Tensor
# * `<date> <location> <air pollutants> (measurement)`
# * Beijing Air Quality
#   * 2,454,305 out of 2,524,536 (35,063 * 12 * 6)
# * Korea Air Quality
#   * 11,270,028 out of 18,368,364 (9,478 * 323 * 6)
# * Madrid Air Quality
#   * 8,036,759 out of 21,587,328 (64,248 * 24 * 14)

# %%
beijing_df = pd.read_csv('../../Data/air_quality/BeijingAirQuality/beijing.tensor', delimiter='\t', header=None)
korea_df = pd.read_csv('../../Data/air_quality/KoreaAirQuality/korea_airquality.tensor', delimiter='\t', header=None)
madrid_df = pd.read_csv('../../Data/air_quality/MadridAirQuality/1hour_madrid.tensor', delimiter='\t', header=None)

# %%
def get_tensor(df):
    start = time.time()

    dims = df[[0,1,2]].max()+1
    tensor = np.empty(dims) * np.nan
    tensor.shape

    for i, row in df.iterrows():
        indices = [[index] for index in np.int64(np.asarray(row[:-1]))]
        tensor[tuple(indices)] = np.double(row[3])

    avg = []
    for i in range(tensor.shape[2]):
        avg.append(np.nanmean(tensor[:,:,i]))
    inds = np.where(np.isnan(tensor))
    for ind in zip(inds[0], inds[1], inds[2]):
        tensor[ind] = avg[ind[-1]]
        
    print(time.time() - start)
    return tensor

# %%
beijing_tensor = get_tensor(beijing_df)
korea_tensor = get_tensor(korea_df)
madrid_tensor = get_tensor(madrid_df)
# Out:
# 334.30233693122864
# 1537.1030325889587
# 1098.3151721954346

# %%
print(beijing_tensor.shape, korea_tensor.shape, madrid_tensor.shape)
# Out:
# (35064, 12, 6) (9479, 323, 6) (64248, 24, 14)

# %%
(n_iter, ul, ll) = (1, 7, -1)
tensor_stream = create_tensor_stream(beijing_tensor, start_to_stream=414, batch_sizes=np.full((99), 350, dtype=int))
results['beijing20'] = online_tensor_decomposition('beijing', beijing_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# results['beijing30'] = online_tensor_decomposition('beijing', beijing_tensor, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 7.627007722854614
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 26897.31417462942
# split: 0 refine: 0
# global fitness 0.9753836879571859
# local fitness 0.7740819509830966
# global running time 15.987162828445435
# local running time 0.08214519240639427
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 26980.89632240543
# global fitness 0.9753071939170187
# local fitness 0.7740589796028943
# global running time 20.03834819793701
# local running time 0.12292310204168763
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 27182.917118992857
# global fitness 0.9751223053093441
# local fitness 0.7740608616625327
# global running time 12.191427230834961
# local running time 0.04421118533972538
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.9757676208530607
# global running time 81.147634267807

# %%
(n_iter, ul, ll) = (1, -1, -1)
tensor_stream = create_tensor_stream(madrid_tensor, start_to_stream=48, batch_sizes=np.full((1284), 50, dtype=int))
results['madrid'] = online_tensor_decomposition('madrid', madrid_tensor, tensor_stream, rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 25.980241298675537
#
#  >> dao rank-50 n_iter-1
# ||A-B||: 21665.59436748316
# split: 0 refine: 0
# global fitness 0.8737511542902294
# local fitness 0.7812662818705411
# global running time 729.2623417377472
# local running time 0.4676774391132723
#
#  >> dtd rank-50 n_iter-1
# ||A-B||: 22017.273946879115
# global fitness 0.8717018617480837
# local fitness 0.7805879110710956
# global running time 651.9250786304474
# local running time 0.40826726758220117
#
#  >> ocp rank-50 n_iter-1
# ||A-B||: 22706.034041914296
# global fitness 0.8676883477177624
# local fitness 0.780872055435393
# global running time 188.6682608127594
# local running time 0.04382432324121303
#
#  >> fcp rank-50 n_iter-1
# global fitness 0.9127858196512515
# global running time 1375.9200806617737

# %%
(n_iter, ul, ll) = (1, 5, -1)
tensor_stream = create_tensor_stream(madrid_tensor, start_to_stream=48, batch_sizes=np.full((1284), 50, dtype=int))
results['madrid'] = online_tensor_decomposition('madrid', madrid_tensor, tensor_stream, methods=['dao'], rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# /home/lucetre/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# -----------------------------------
# making init decomposition result: 3.7188706398010254
#
#  >> dao rank-50 n_iter-1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-3ffd7007048e> in <module>
#       1 (n_iter, ul, ll) = (1, 5, -1)
#       2 tensor_stream = create_tensor_stream(madrid_tensor, start_to_stream=48, batch_sizes=np.full((1284), 50, dtype=int))
# ----> 3 results['madrid'] = online_tensor_decomposition('madrid', madrid_tensor, tensor_stream, methods=['dao'], rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
#
# ~/dmlab/online-tensor-decomposition/Proposed Method/online_tensor_decomposition.py in online_tensor_decomposition(dataset, X, X_stream, rank, n_iter, ul, ll, verbose, methods)
#     443         tensor_est = construct_tensor(ktensors[0][1])
#     444         for (weights, factors) in ktensors[1:]:
# --> 445             tensor_est = tl.tensor(tl.concatenate((tensor_est, construct_tensor(factors))))
#     446         global_error_norm = compare_tensors(X, tensor_est)
#     447 #        print('Elapsed Time:', time.time() - begin)
#
# ~/dmlab/online-tensor-decomposition/Proposed Method/online_tensor_decomposition.py in construct_tensor(factors)
#      49 def construct_tensor(factors):
#      50     weights = tl.ones(factors[0].shape[1])
# ---> 51     est_tensor = tl.kruskal_to_tensor((weights, factors))
#      52     return est_tensor
#      53
#
# ~/.local/lib/python3.8/site-packages/tensorly/kruskal_tensor.py in kruskal_to_tensor(kruskal_tensor, mask)
#     183
#     184     if mask is None:
# --> 185         full_tensor = T.dot(factors[0]*weights,
#     186                              T.transpose(khatri_rao(factors, skip_matrix=0)))
#     187     else:
#
# ~/.local/lib/python3.8/site-packages/tensorly/backend/__init__.py in inner(*args, **kwargs)
#     158
#     159     def inner(*args, **kwargs):
# --> 160         return _get_backend_method(name)(*args, **kwargs)
#     161
#     162     # We don't use `functools.wraps` here because some of the dispatched
#
# ~/.local/lib/python3.8/site-packages/tensorly/backend/numpy_backend.py in dot(a, b)
#      36     @staticmethod
#      37     def dot(a, b):
# ---> 38         return a.dot(b)
#      39
#      40     @staticmethod
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ### Hall from OLSTEC (done)
# * `hall1-200.mat`: 144 * 176 * 200 => 200 * 144 * 176
# * `hall_144x100_frame2900-3899_pan.mat`: 144 * 100 * 1000 => 1000 * 144 * 100

# %%
from scipy.io import loadmat
import h5py

hall1 = loadmat('../Data/hall/hall1-200.mat')['XO']
hall1 = np.moveaxis(hall1, -1, 0)
hall1 = hall1.reshape(200, 144, 176, order='F')

with h5py.File('../Data/hall/hall_144x100_frame2900-3899_pan.mat', 'r') as f:
    hall2 = np.array(f['X0'])
    hall2 = hall2.reshape(1000, 144, 100, order='F')
    
hall1_tensor = tl.tensor(hall1, dtype='f')
hall2_tensor = tl.tensor(hall2, dtype='f')
print(hall1_tensor.shape, hall2_tensor.shape)
# make_video(hall1, 'hall1.avi', False)
# make_video(hall2, 'hall2.avi', False)
# Out:
# (200, 144, 176) (1000, 144, 100)

# %%
(n_iter, ul, ll) = (1, 0.5, 0.1)
tensor_stream = create_tensor_stream(hall1_tensor, start_to_stream=10, batch_sizes=np.full((19), 10, dtype=int))
results['hall1-20'] = online_tensor_decomposition('hall1', hall1_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall1-25'] = online_tensor_decomposition('hall1', hall1_tensor, tensor_stream, rank=25, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall1-30'] = online_tensor_decomposition('hall1', hall1_tensor, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall1-35'] = online_tensor_decomposition('hall1', hall1_tensor, tensor_stream, rank=35, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall1-40'] = online_tensor_decomposition('hall1', hall1_tensor, tensor_stream, rank=40, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 1.4002480506896973
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 46398.42388416413
# split: 3 refine: 5
# global fitness 0.8688472525363344
# local fitness 0.882028744112595
# global running time 8.390179872512817
# local running time 0.060151100158691406
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 47760.07528828131
# global fitness 0.8649983217367975
# local fitness 0.866170891224457
# global running time 2.2904038429260254
# local running time 0.044301936500950864
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 48642.68042886453
# global fitness 0.8625034936925942
# local fitness 0.8682946791048951
# global running time 1.6394307613372803
# local running time 0.009324174178274055
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.8763017020613562
# global running time 33.148178815841675
# -----------------------------------
# making init decomposition result: 1.6646089553833008
#
#  >> dao rank-25 n_iter-1
# ||A-B||: 42489.66915504855
# split: 6 refine: 6
# global fitness 0.8798959882253945
# local fitness 0.8967213413718499
# global running time 16.764986515045166
# local running time 0.06638235794870477
#
#  >> dtd rank-25 n_iter-1
# ||A-B||: 45501.00338595471
# global fitness 0.8713839586163559
# local fitness 0.8725752113510867
# global running time 2.658205509185791
# local running time 0.04962662646644994
#
#  >> ocp rank-25 n_iter-1
# ||A-B||: 46328.01735783349
# global fitness 0.8690462681190768
# local fitness 0.8749664361129164
# global running time 1.881960391998291
# local running time 0.00914302625154194
#
#  >> fcp rank-25 n_iter-1
# global fitness 0.8854516196035908
# global running time 42.48250603675842
# -----------------------------------
# making init decomposition result: 2.035435676574707
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 37573.947158448245
# split: 9 refine: 2
# global fitness 0.8937910818870081
# local fitness 0.9038334188359247
# global running time 25.424301862716675
# local running time 0.03981935350518478
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 43315.22488444506
# global fitness 0.8775624196894237
# local fitness 0.8772072742040349
# global running time 3.316685914993286
# local running time 0.06492745248894942
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 44613.79515940268
# global fitness 0.873891798037263
# local fitness 0.879643259799568
# global running time 2.3028578758239746
# local running time 0.010941003498278166
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.8911778239407536
# global running time 52.519118309020996
# -----------------------------------
# making init decomposition result: 2.460442304611206
#
#  >> dao rank-35 n_iter-1
# ||A-B||: 35831.85734764532
# split: 9 refine: 3
# global fitness 0.8987153841776563
# local fitness 0.9098732963091184
# global running time 27.783955335617065
# local running time 0.055703351372166685
#
#  >> dtd rank-35 n_iter-1
# ||A-B||: 41469.26610561469
# global fitness 0.8827803246370722
# local fitness 0.882026766273905
# global running time 3.801480531692505
# local running time 0.06753161079005192
#
#  >> ocp rank-35 n_iter-1
# ||A-B||: 42641.545127515674
# global fitness 0.8794666859044254
# local fitness 0.8842468386508338
# global running time 2.7492446899414062
# local running time 0.012415973763716849
#
#  >> fcp rank-35 n_iter-1
# global fitness 0.8964334776785856
# global running time 58.0099515914917
# -----------------------------------
# making init decomposition result: 3.080338478088379
#
#  >> dao rank-40 n_iter-1
# ||A-B||: 33984.736417390464
# split: 10 refine: 3
# global fitness 0.903936574136724
# local fitness 0.9169227921678218
# global running time 35.20059299468994
# local running time 0.0744124086279618
#
#  >> dtd rank-40 n_iter-1
# ||A-B||: 40654.57299543607
# global fitness 0.8850831881999898
# local fitness 0.883874238076779
# global running time 4.847224712371826
# local running time 0.09002572611758583
#
#  >> ocp rank-40 n_iter-1
# ||A-B||: 42339.86289528517
# global fitness 0.8803194401642852
# local fitness 0.8859854818498436
# global running time 3.409952402114868
# local running time 0.0152018572154798
#
#  >> fcp rank-40 n_iter-1
# global fitness 0.9004924175179032
# global running time 70.07118248939514

# %%
plot(('hall1-20', 'hall1-25', 'hall1-30', 'hall1-35', 'hall1-40'), 'hall1')

# %%
(n_iter, ul, ll) = (1, 2, 1.5)
tensor_stream = create_tensor_stream(hall2_tensor, start_to_stream=20, batch_sizes=np.full((49), 20, dtype=int))
results['hall2-10'] = online_tensor_decomposition('hall2', hall2_tensor, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall2-20'] = online_tensor_decomposition('hall2', hall2_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall2-30'] = online_tensor_decomposition('hall2', hall2_tensor, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall2-40'] = online_tensor_decomposition('hall2', hall2_tensor, tensor_stream, rank=40, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall2-50'] = online_tensor_decomposition('hall2', hall2_tensor, tensor_stream, rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 0.6727252006530762
#
#  >> dao rank-10 n_iter-1
# ||A-B||: 134532.4210496825
# split: 2 refine: 1
# global fitness 0.7774641496268491
# local fitness 0.7839918902677041
# global running time 3.9373223781585693
# local running time 0.026912971418731068
#
#  >> dtd rank-10 n_iter-1
# ||A-B||: 139995.78783292862
# global fitness 0.7684269602005092
# local fitness 0.7704227037047743
# global running time 2.8649520874023438
# local running time 0.023868035297004545
#
#  >> ocp rank-10 n_iter-1
# ||A-B||: 140463.2725418385
# global fitness 0.7676536736839803
# local fitness 0.7729817897286851
# global running time 2.032331705093384
# local running time 0.006645445920983139
#
#  >> fcp rank-10 n_iter-1
# global fitness 0.7889151994626342
# global running time 136.39763045310974
# -----------------------------------
# making init decomposition result: 1.114673376083374
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 116921.93323456521
# split: 4 refine: 3
# global fitness 0.8065944131785314
# local fitness 0.8177841657331743
# global running time 10.763614416122437
# local running time 0.0531580740091752
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 123718.51947593015
# global fitness 0.7953518882387769
# local fitness 0.7971393667647221
# global running time 4.27078104019165
# local running time 0.04337311764152683
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 126986.50197768243
# global fitness 0.7899461781552317
# local fitness 0.7965265183440562
# global running time 2.630434274673462
# local running time 0.009303983376950634
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.8207721399194903
# global running time 271.0551698207855
# -----------------------------------
# making init decomposition result: 2.2082788944244385
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 88957.8757251223
# split: 18 refine: 6
# global fitness 0.8528509606277848
# local fitness 0.8694771778656004
# global running time 47.68290448188782
# local running time 0.056581584774717995
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 112478.24752718376
# global fitness 0.8139449043833091
# local fitness 0.815603013287681
# global running time 6.062633514404297
# local running time 0.06508327017025071
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 115834.72816603658
# global fitness 0.8083928057337777
# local fitness 0.8151086428364092
# global running time 3.6597204208374023
# local running time 0.009007736128203723
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.8369461407732692
# global running time 406.3843512535095
# -----------------------------------
# making init decomposition result: 2.7132887840270996
#
#  >> dao rank-40 n_iter-1
# ||A-B||: 76066.08054123937
# split: 24 refine: 3
# global fitness 0.8741758322215429
# local fitness 0.8849235075517852
# global running time 79.85781478881836
# local running time 0.055441102203057736
#
#  >> dtd rank-40 n_iter-1
# ||A-B||: 105852.36624664563
# global fitness 0.8249050589225007
# local fitness 0.8258947938142329
# global running time 7.87943172454834
# local running time 0.09199429531486666
#
#  >> ocp rank-40 n_iter-1
# ||A-B||: 108553.11679618085
# global fitness 0.82043763155074
# local fitness 0.8265888380918328
# global running time 4.339430809020996
# local running time 0.012858420002217196
#
#  >> fcp rank-40 n_iter-1
# global fitness 0.8481048536951212
# global running time 540.9547789096832
# -----------------------------------
# making init decomposition result: 4.230155944824219
#
#  >> dao rank-50 n_iter-1
# ||A-B||: 73681.35445503349
# split: 24 refine: 2
# global fitness 0.8781205099680682
# local fitness 0.8885615618070627
# global running time 104.27781224250793
# local running time 0.07529565266200475
#
#  >> dtd rank-50 n_iter-1
# ||A-B||: 99682.55337036963
# global fitness 0.8351108111445487
# local fitness 0.8345740400335756
# global running time 10.6487557888031
# local running time 0.11030544553484235
#
#  >> ocp rank-50 n_iter-1
# ||A-B||: 104794.22026209328
# global fitness 0.8266553836000319
# local fitness 0.8328871454004994
# global running time 5.946784973144531
# local running time 0.014554145384807976
#
#  >> fcp rank-50 n_iter-1
# global fitness 0.8561305011664528
# global running time 709.3258490562439

# %%
plot(('hall2-10', 'hall2-20', 'hall2-30', 'hall2-40', 'hall2-50'), 'hall2')
