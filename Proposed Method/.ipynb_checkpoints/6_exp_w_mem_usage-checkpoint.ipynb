# %%
import time
import math
import numpy as np
import tensorly as tl
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from brokenaxes import brokenaxes
from online_tensor_decomposition import *

# %%
# for sample video
from cv2 import VideoWriter, VideoWriter_fourcc, imshow, imwrite

def make_video(tensor, filename, isColor=True):
    start = time.time()
    height = tensor.shape[1]
    width = tensor.shape[2]
    FPS = 24

    fourcc = VideoWriter_fourcc(*'MP42')
    video = VideoWriter(filename, fourcc, float(FPS), (width, height), isColor)

    for frame in tensor:
        video.write(np.uint8(frame))
    video.release()
    print('created', filename, time.time()-start)

# %%
results = {}

# %%
def plot_local(datasets, name):
    def plot():
        points  = []
        for dataset in datasets:
            if dataset in results:
                for lib in libs:
                    if lib in results[dataset]:
                        point = [lib, dataset, [results[dataset][lib][3]], [results[dataset][lib][1]]]
                        points.append(point)


#         print(points)

        bax = brokenaxes(xscale='log')
#             bax = brokenaxes(xscale='log', subplot_spec=sps1)
        for point in points :
            lib, data, x, y = point
            if len(x) != 0:
                if x[0] != 0 and y[0] != 0:
                    bax.plot(x, y, label=lib,
                             c= dct[lib],  marker=dct1[data],
                            mfc='none', ms = 10, mew = 1.8)
#         bax.set_ylim([0.97,0.99])
#         bax.set_yscale('log') 
#         bax.set_xscale('log')


#         bax.tick_params(axis = 'y', labelsize =8)
        bax.set_ylabel('Average of Local Fitness', size = 10, labelpad=50)
        bax.set_xlabel('Average of Local Running Time (s)', size = 10, labelpad=25)  ### Labelpad > space btw xaxis and xlabel
        plt.subplots_adjust(hspace=0.1, bottom = 0.4 , left = 0.23, top = 0.9) ### Plot to remove whitespace of plot 
#         plt.show()
        plt.savefig(f'./plots/{name}_local.pdf',bbox_inches = 'tight', pad_inches = 0)

    markers = ("o", "x", "s", "^", "4")
    colors = ('dodgerblue','mediumseagreen', 'hotpink', '#fba84a')

    libs = ("dao", "dtd", "ocp", 'fcp')
    f = lambda m,c: plt.plot([],[], color=c, marker = m,
                             mfc='none', ms = 10, mew = 1.8,
                                ls="none")[0]
    f2 = lambda c: plt.plot([],[],marker='.', color=c, )[0]

    dct = {}
    dct1 = {}

    for color, lib in zip(colors, libs):
        dct[lib] = color

    for data, marker in zip(datasets, markers):
        dct1[data] = marker
    
    fig = plt.figure(figsize = (4, 4), dpi = 150,)   ### figsize = (row, col), dpi > resolution(?)
#     sps1, sps2 = GridSpec(1,2)
    plot()

# %%
def plot_global(datasets, name):
    def plot():
        points  = []
        for dataset in datasets:
            if dataset in results:
                for lib in libs:
                    if lib in results[dataset]:
                        point = [lib, dataset, [results[dataset][lib][2]], [results[dataset][lib][0]]]
                        points.append(point)
#         print(points)

        bax = brokenaxes(xscale='log')
#             bax = brokenaxes(xscale='log', subplot_spec=sps2)
        for point in points :
            lib, data, x, y = point
            if len(x) != 0:
                if x[0] != 0 and y[0] != 0:
                    bax.plot(x, y, label=lib,
                             c= dct[lib],  marker=dct1[data],
                            mfc='none', ms = 10, mew = 1.8)

#         bax.set_ylim([0.97,0.99])
#         bax.set_xscale('log') 
        bax.set_ylabel('Global Fitness', size = 10, labelpad=50)
        bax.set_xlabel('Global Running Time (s)', size = 10, labelpad=25)  ### Labelpad > space btw xaxis and xlabel
        plt.subplots_adjust(hspace=0.1, bottom = 0.4 , left = 0.23, top = 0.9) ### Plot to remove whitespace of plot 
#         plt.show()
        plt.savefig(f'./plots/{name}_global.pdf',bbox_inches = 'tight', pad_inches = 0)

    markers = ("o", "x", "s", "^", "4")
    colors = ('dodgerblue','mediumseagreen', 'hotpink', '#fba84a')

    libs = ("dao", "dtd", "ocp", 'fcp')
    f = lambda m,c: plt.plot([],[], color=c, marker = m,
                             mfc='none', ms = 10, mew = 1.8,
                                ls="none")[0]
    f2 = lambda c: plt.plot([],[],marker='.', color=c, )[0]

    dct = {}
    dct1 = {}

    for color, lib in zip(colors, libs):
        dct[lib] = color

    for data, marker in zip(datasets, markers):
        dct1[data] = marker
    
    fig = plt.figure(figsize = (4, 4), dpi = 150,)   ### figsize = (row, col), dpi > resolution(?)
#     sps1, sps2 = GridSpec(1,2)
    plot()

# %%
def plot_mem(datasets, name):
    colors = ('dodgerblue','mediumseagreen', 'hotpink', '#fba84a')

    libs = ("dao", "dtd", "ocp", 'fcp')

    # create plot
    fig = plt.figure(figsize = (4, 4), dpi = 150,)
    index = np.arange(5)
    bar_width = 0.2

    for i, (color, lib) in enumerate(zip(colors, libs)):
        mem_list = [results[dataset][lib][4] for dataset in datasets]
        rects1 = plt.bar(index + bar_width*i, mem_list, bar_width, color=color, label=lib)

    plt.xlabel('Datasets')
    plt.ylabel('Memory Usage (byte)')
    plt.yscale('log')
    plt.xticks(index + bar_width*1.5, ('Synthetic', 'Video', 'Stock', 'Hall', 'Korea'))

    plt.savefig(f'./plots/{name}_mem.pdf', bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### Synthetic Data

# %%
import csv
synthetic_data = tl.tensor(np.zeros([1000, 10, 20, 30], dtype='f'))

for i in range(200):
    start = time.time()
    with open('../Data/synthetic_data/data_normal/data{}.tensor'.format(i)) as file:
        reader = csv.reader(file, delimiter='\t')    
        for row in reader:
            indices = [[index] for index in np.int64(np.asarray(row[:-1]))-1]
            synthetic_data[tuple(indices)] = np.double(row[-1])
    print('>> synthetic_data{} loaded '.format(i), time.time() - start)
# Out:
# >> synthetic_data0 loaded  0.8089854717254639
# >> synthetic_data1 loaded  0.7399237155914307
# >> synthetic_data2 loaded  0.8001923561096191
# >> synthetic_data3 loaded  0.7704532146453857
# >> synthetic_data4 loaded  0.7719612121582031
# >> synthetic_data5 loaded  0.7916927337646484
# >> synthetic_data6 loaded  0.8202805519104004
# >> synthetic_data7 loaded  0.7268617153167725
# >> synthetic_data8 loaded  0.7543210983276367
# >> synthetic_data9 loaded  0.9587233066558838
# >> synthetic_data10 loaded  0.8762302398681641
# >> synthetic_data11 loaded  0.746635913848877
# >> synthetic_data12 loaded  0.9298222064971924
# >> synthetic_data13 loaded  0.8807938098907471
# >> synthetic_data14 loaded  0.7888236045837402
# >> synthetic_data15 loaded  0.8984696865081787
# >> synthetic_data16 loaded  0.7626657485961914
# >> synthetic_data17 loaded  0.8112266063690186
# >> synthetic_data18 loaded  0.7738268375396729
# >> synthetic_data19 loaded  0.7536637783050537
# >> synthetic_data20 loaded  0.7428748607635498
# >> synthetic_data21 loaded  0.7345907688140869
# >> synthetic_data22 loaded  0.742403507232666
# >> synthetic_data23 loaded  0.7483065128326416
# >> synthetic_data24 loaded  0.7146508693695068
# >> synthetic_data25 loaded  0.6758279800415039
# >> synthetic_data26 loaded  0.7262997627258301
# >> synthetic_data27 loaded  0.7433135509490967
# >> synthetic_data28 loaded  0.7370922565460205
# >> synthetic_data29 loaded  0.7263097763061523
# >> synthetic_data30 loaded  0.7378597259521484
# >> synthetic_data31 loaded  0.8064594268798828
# >> synthetic_data32 loaded  0.7029180526733398
# >> synthetic_data33 loaded  0.7826786041259766
# >> synthetic_data34 loaded  0.7789461612701416
# >> synthetic_data35 loaded  0.781794548034668
# >> synthetic_data36 loaded  0.7591378688812256
# >> synthetic_data37 loaded  0.7608611583709717
# >> synthetic_data38 loaded  0.6991398334503174
# >> synthetic_data39 loaded  0.7509794235229492
# >> synthetic_data40 loaded  0.74696946144104
# >> synthetic_data41 loaded  0.794924259185791
# >> synthetic_data42 loaded  0.7460289001464844
# >> synthetic_data43 loaded  0.7528789043426514
# >> synthetic_data44 loaded  0.7549190521240234
# >> synthetic_data45 loaded  0.7415299415588379
# >> synthetic_data46 loaded  0.7218701839447021
# >> synthetic_data47 loaded  0.734375
# >> synthetic_data48 loaded  0.7300460338592529
# >> synthetic_data49 loaded  0.7913808822631836
# >> synthetic_data50 loaded  0.7810566425323486
# >> synthetic_data51 loaded  0.7736475467681885
# >> synthetic_data52 loaded  0.7464122772216797
# >> synthetic_data53 loaded  0.7407963275909424
# >> synthetic_data54 loaded  0.7370522022247314
# >> synthetic_data55 loaded  0.8346140384674072
# >> synthetic_data56 loaded  0.757455587387085
# >> synthetic_data57 loaded  0.7723701000213623
# >> synthetic_data58 loaded  0.7517974376678467
# >> synthetic_data59 loaded  0.7337155342102051
# >> synthetic_data60 loaded  0.7015037536621094
# >> synthetic_data61 loaded  0.7395153045654297
# >> synthetic_data62 loaded  0.8076834678649902
# >> synthetic_data63 loaded  0.7736515998840332
# >> synthetic_data64 loaded  0.7718749046325684
# >> synthetic_data65 loaded  0.7538464069366455
# >> synthetic_data66 loaded  0.7478485107421875
# >> synthetic_data67 loaded  0.7498416900634766
# >> synthetic_data68 loaded  0.7547752857208252
# >> synthetic_data69 loaded  0.7343673706054688
# >> synthetic_data70 loaded  0.7452666759490967
# >> synthetic_data71 loaded  0.7566053867340088
# >> synthetic_data72 loaded  0.749157190322876
# >> synthetic_data73 loaded  0.7328355312347412
# >> synthetic_data74 loaded  0.7616286277770996
# >> synthetic_data75 loaded  0.7488505840301514
# >> synthetic_data76 loaded  0.7994635105133057
# >> synthetic_data77 loaded  0.7611174583435059
# >> synthetic_data78 loaded  0.7442843914031982
# >> synthetic_data79 loaded  0.7415828704833984
# >> synthetic_data80 loaded  0.762423038482666
# >> synthetic_data81 loaded  0.7449140548706055
# >> synthetic_data82 loaded  0.7136616706848145
# >> synthetic_data83 loaded  0.738518238067627
# >> synthetic_data84 loaded  0.6855249404907227
# >> synthetic_data85 loaded  0.6792497634887695
# >> synthetic_data86 loaded  0.6755008697509766
# >> synthetic_data87 loaded  0.701061487197876
# >> synthetic_data88 loaded  0.7337310314178467
# >> synthetic_data89 loaded  0.7418086528778076
# >> synthetic_data90 loaded  0.7975425720214844
# >> synthetic_data91 loaded  0.7641737461090088
# >> synthetic_data92 loaded  0.8320977687835693
# >> synthetic_data93 loaded  0.7822089195251465
# >> synthetic_data94 loaded  0.7351639270782471
# >> synthetic_data95 loaded  0.7531461715698242
# >> synthetic_data96 loaded  0.7995388507843018
# >> synthetic_data97 loaded  0.7535350322723389
# >> synthetic_data98 loaded  0.8906619548797607
# >> synthetic_data99 loaded  0.7821450233459473
# >> synthetic_data100 loaded  0.7782473564147949
# >> synthetic_data101 loaded  0.7918965816497803
# >> synthetic_data102 loaded  0.7942492961883545
# >> synthetic_data103 loaded  0.883436918258667
# >> synthetic_data104 loaded  0.8281612396240234
# >> synthetic_data105 loaded  0.7609374523162842
# >> synthetic_data106 loaded  0.7476184368133545
# >> synthetic_data107 loaded  0.7475028038024902
# >> synthetic_data108 loaded  0.8677585124969482
# >> synthetic_data109 loaded  0.7684383392333984
# >> synthetic_data110 loaded  0.7236886024475098
# >> synthetic_data111 loaded  0.7436764240264893
# >> synthetic_data112 loaded  0.7310829162597656
# >> synthetic_data113 loaded  0.7210524082183838
# >> synthetic_data114 loaded  0.6977107524871826
# >> synthetic_data115 loaded  0.6838202476501465
# >> synthetic_data116 loaded  0.6910927295684814
# >> synthetic_data117 loaded  0.6857719421386719
# >> synthetic_data118 loaded  0.6820521354675293
# >> synthetic_data119 loaded  0.7037379741668701
# >> synthetic_data120 loaded  0.7311317920684814
# >> synthetic_data121 loaded  0.7488198280334473
# >> synthetic_data122 loaded  0.7273390293121338
# >> synthetic_data123 loaded  0.7184374332427979
# >> synthetic_data124 loaded  0.7342002391815186
# >> synthetic_data125 loaded  0.7264754772186279
# >> synthetic_data126 loaded  0.7270193099975586
# >> synthetic_data127 loaded  0.7564663887023926
# >> synthetic_data128 loaded  0.7475147247314453
# >> synthetic_data129 loaded  0.7814335823059082
# >> synthetic_data130 loaded  0.7549879550933838
# >> synthetic_data131 loaded  0.734574556350708
# >> synthetic_data132 loaded  0.7416462898254395
# >> synthetic_data133 loaded  0.7281031608581543
# >> synthetic_data134 loaded  0.6896982192993164
# >> synthetic_data135 loaded  0.6940040588378906
# >> synthetic_data136 loaded  0.6872568130493164
# >> synthetic_data137 loaded  0.6952710151672363
# >> synthetic_data138 loaded  0.691500186920166
# >> synthetic_data139 loaded  0.6872677803039551
# >> synthetic_data140 loaded  0.6953020095825195
# >> synthetic_data141 loaded  0.6788384914398193
# >> synthetic_data142 loaded  0.7118411064147949
# >> synthetic_data143 loaded  0.7582790851593018
# >> synthetic_data144 loaded  0.7513420581817627
# >> synthetic_data145 loaded  0.8069906234741211
# >> synthetic_data146 loaded  0.7624557018280029
# >> synthetic_data147 loaded  0.7161166667938232
# >> synthetic_data148 loaded  0.7447199821472168
# >> synthetic_data149 loaded  0.7305500507354736
# >> synthetic_data150 loaded  0.7571074962615967
# >> synthetic_data151 loaded  0.7444033622741699
# >> synthetic_data152 loaded  0.7537319660186768
# >> synthetic_data153 loaded  0.7474133968353271
# >> synthetic_data154 loaded  0.7537963390350342
# >> synthetic_data155 loaded  0.750934362411499
# >> synthetic_data156 loaded  0.7436888217926025
# >> synthetic_data157 loaded  0.7565577030181885
# >> synthetic_data158 loaded  0.7414579391479492
# >> synthetic_data159 loaded  0.787111759185791
# >> synthetic_data160 loaded  0.7554564476013184
# >> synthetic_data161 loaded  0.7580101490020752
# >> synthetic_data162 loaded  0.7511522769927979
# >> synthetic_data163 loaded  0.7553620338439941
# >> synthetic_data164 loaded  0.7804598808288574
# >> synthetic_data165 loaded  0.7580606937408447
# >> synthetic_data166 loaded  0.7480015754699707
# >> synthetic_data167 loaded  0.749732255935669
# >> synthetic_data168 loaded  0.728992223739624
# >> synthetic_data169 loaded  0.7145891189575195
# >> synthetic_data170 loaded  0.7546777725219727
# >> synthetic_data171 loaded  0.7555997371673584
# >> synthetic_data172 loaded  0.7668664455413818
# >> synthetic_data173 loaded  0.7404263019561768
# >> synthetic_data174 loaded  0.7574379444122314
# >> synthetic_data175 loaded  0.6973261833190918
# >> synthetic_data176 loaded  0.7007546424865723
# >> synthetic_data177 loaded  0.7024495601654053
# >> synthetic_data178 loaded  0.754645586013794
# >> synthetic_data179 loaded  0.7403662204742432
# >> synthetic_data180 loaded  0.7640213966369629
# >> synthetic_data181 loaded  0.7662584781646729
# >> synthetic_data182 loaded  0.7810144424438477
# >> synthetic_data183 loaded  0.7809889316558838
# >> synthetic_data184 loaded  0.7605459690093994
# >> synthetic_data185 loaded  0.7536787986755371
# >> synthetic_data186 loaded  0.7645189762115479
# >> synthetic_data187 loaded  0.773984432220459
# >> synthetic_data188 loaded  0.7731184959411621
# >> synthetic_data189 loaded  0.7521581649780273
# >> synthetic_data190 loaded  0.7490777969360352
# >> synthetic_data191 loaded  0.7310824394226074
# >> synthetic_data192 loaded  0.7076642513275146
# >> synthetic_data193 loaded  0.6929669380187988
# >> synthetic_data194 loaded  0.683147668838501
# >> synthetic_data195 loaded  0.6832475662231445
# >> synthetic_data196 loaded  0.6927571296691895
# >> synthetic_data197 loaded  0.7152023315429688
# >> synthetic_data198 loaded  0.7130236625671387
# >> synthetic_data199 loaded  0.7403631210327148

# %% [markdown]
# ### Sample Video

# %%
import csv
sample_video = tl.tensor(np.zeros([205, 240, 320, 3], dtype='d'))

for i in range(41):
    start = time.time()
    with open('../Data/sample_video/data/video{}.tensor'.format(i)) as file:
        reader = csv.reader(file, delimiter='\t')    
        for row in reader:
            indices = [[index] for index in np.int64(np.asarray(row[:-1]))-1]
            sample_video[tuple(indices)] = np.double(row[-1])
    print('>> sample_video{} loaded '.format(i), time.time() - start)
# Out:
# >> sample_video0 loaded  29.22272753715515
# >> sample_video1 loaded  29.805198192596436
# >> sample_video2 loaded  29.769192218780518
# >> sample_video3 loaded  29.838042497634888
# >> sample_video4 loaded  30.404560327529907
# >> sample_video5 loaded  30.48759627342224
# >> sample_video6 loaded  29.66261863708496
# >> sample_video7 loaded  29.75973343849182
# >> sample_video8 loaded  29.328087091445923
# >> sample_video9 loaded  29.36920714378357
# >> sample_video10 loaded  29.041115283966064
# >> sample_video11 loaded  29.776947259902954
# >> sample_video12 loaded  29.553614854812622
# >> sample_video13 loaded  29.903693675994873
# >> sample_video14 loaded  29.468895435333252
# >> sample_video15 loaded  29.817434549331665
# >> sample_video16 loaded  27.068209648132324
# >> sample_video17 loaded  24.02576971054077
# >> sample_video18 loaded  24.411084413528442
# >> sample_video19 loaded  24.581892728805542
# >> sample_video20 loaded  24.296696662902832
# >> sample_video21 loaded  24.29754948616028
# >> sample_video22 loaded  24.428504467010498
# >> sample_video23 loaded  24.478832721710205
# >> sample_video24 loaded  24.489866971969604
# >> sample_video25 loaded  24.402048110961914
# >> sample_video26 loaded  24.3495192527771
# >> sample_video27 loaded  24.157915830612183
# >> sample_video28 loaded  24.216499090194702
# >> sample_video29 loaded  24.584920406341553
# >> sample_video30 loaded  24.6293625831604
# >> sample_video31 loaded  24.409510612487793
# >> sample_video32 loaded  24.32131004333496
# >> sample_video33 loaded  24.28522539138794
# >> sample_video34 loaded  24.60248327255249
# >> sample_video35 loaded  24.36040687561035
# >> sample_video36 loaded  24.298003673553467
# >> sample_video37 loaded  24.26122760772705
# >> sample_video38 loaded  24.377915859222412
# >> sample_video39 loaded  24.335859775543213
# >> sample_video40 loaded  24.599018096923828

# %% [markdown]
# ### Stock

# %%
import csv

stock2_tensor = tl.tensor(np.zeros([3089, 140, 5], dtype='d'))
start = time.time()
with open('../Data/stock/KOSPI140.tensor') as file:
    reader = csv.reader(file, delimiter='\t')    
    for row in reader:
        indices = np.asarray([index for index in np.int64(np.asarray(row[:-1]))])[[1, 0, 2]]
        stock2_tensor[tuple(indices)] = np.double(row[-1])
print('>> stock2_tensor loaded ', time.time() - start)
# Out:
# >> stock2_tensor loaded  36.77640414237976

# %% [markdown]
# ### Hall from OLSTEC
# * `hall1-200.mat`: 144 * 176 * 200 => 200 * 144 * 176
# * `hall_144x100_frame2900-3899_pan.mat`: 144 * 100 * 1000 => 1000 * 144 * 100

# %%
from scipy.io import loadmat
import h5py

hall1 = loadmat('../Data/hall/hall1-200.mat')['XO']
hall1 = np.moveaxis(hall1, -1, 0)
hall1 = hall1.reshape(200, 144, 176, order='F')

with h5py.File('../Data/hall/hall_144x100_frame2900-3899_pan.mat', 'r') as f:
    hall2 = np.array(f['X0'])
    hall2 = hall2.reshape(1000, 144, 100, order='F')
    
hall1_tensor = tl.tensor(hall1, dtype='f')
hall2_tensor = tl.tensor(hall2, dtype='f')
print(hall1_tensor.shape, hall2_tensor.shape)
# make_video(hall1, 'hall1.avi', False)
# make_video(hall2, 'hall2.avi', False)
# Out:
# (200, 144, 176) (1000, 144, 100)

# %% [markdown]
# ### Air Quality Tensor
# * `<date> <location> <air pollutants> (measurement)`
# * Beijing Air Quality
#   * 2,454,305 out of 2,524,536 (35,063 * 12 * 6)
# * Korea Air Quality
#   * 11,270,028 out of 18,368,364 (9,478 * 323 * 6)
# * Madrid Air Quality
#   * 8,036,759 out of 21,587,328 (64,248 * 24 * 14)

# %%
# beijing_df = pd.read_csv('../../Data/air_quality/BeijingAirQuality/beijing.tensor', delimiter='\t', header=None)
korea_df = pd.read_csv('../../Data/air_quality/KoreaAirQuality/korea_airquality.tensor', delimiter='\t', header=None)
# madrid_df = pd.read_csv('../../Data/air_quality/MadridAirQuality/1hour_madrid.tensor', delimiter='\t', header=None)

# %%
def get_tensor(df):
    start = time.time()

    dims = df[[0,1,2]].max()+1
    tensor = np.empty(dims) * np.nan
    tensor.shape

    for i, row in df.iterrows():
        indices = [[index] for index in np.int64(np.asarray(row[:-1]))]
        tensor[tuple(indices)] = np.double(row[3])

    avg = []
    for i in range(tensor.shape[2]):
        avg.append(np.nanmean(tensor[:,:,i]))
    inds = np.where(np.isnan(tensor))
    for ind in zip(inds[0], inds[1], inds[2]):
        tensor[ind] = avg[ind[-1]]
        
    print(time.time() - start)
    return tensor

# %%
# beijing_tensor = get_tensor(beijing_df)
korea_tensor = get_tensor(korea_df)
# madrid_tensor = get_tensor(madrid_df)
# Out:
# 1528.299346446991

# %% [markdown]
# ---
# # Experiment #1

# %%
# synthetic
(n_iter, ul, ll) = (1, 1.2, 1.1)
tensor_stream = create_tensor_stream(synthetic_data, start_to_stream=10, batch_sizes=np.full((99), 10, dtype=int))
results['synthetic-10'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['synthetic-20'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['synthetic-30'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['synthetic-40'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=40, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['synthetic-50'] = online_tensor_decomposition('synthetic', synthetic_data, tensor_stream, rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 3.0019285678863525
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 168427.65934522531
# split: 4 refine: 0
# global fitness 0.31423424352567686
# local fitness 0.314087552392025
# global running time 15.939834117889404
# local running time 0.04025915897253788
# memory usage 496
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 231000.28883298358
# global fitness 0.05946512328689624
# local fitness 0.0641038994804517
# global running time 6.9725682735443115
# local running time 0.03729789184801506
# memory usage 464
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 231042.70980339267
# global fitness 0.059292403147127914
# local fitness 0.06413768111585183
# global running time 4.16307520866394
# local running time 0.009571622116397125
# memory usage 8160
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.11470824499596788
# global running time 38.07814407348633
# memory usage 24000248

# %%
datasets = ('synthetic-10', 'synthetic-20', 'synthetic-30', 'synthetic-40', 'synthetic-50')
plot_global(datasets, 'E1_synthetic')
plot_local(datasets, 'E1_synthetic')

# %%
# video
(n_iter, ul, ll) = (1, 6, 2)
tensor_stream = create_tensor_stream(sample_video, start_to_stream=5, batch_sizes=np.full((40), 5, dtype=int))
results['video-10'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video-20'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video-30'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video-40'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=40, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['video-50'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=50, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 11.2359619140625
#
#  >> dao rank-10 n_iter-1
# ||A-B||: 146587.49744316228
# split: 3 refine: 10
# global fitness 0.8357747740823623
# local fitness 0.8564193237872809
# global running time 52.94744396209717
# local running time 0.23569840788841248
# memory usage 552
#
#  >> dtd rank-10 n_iter-1
# ||A-B||: 189218.9613186605
# global fitness 0.7880137991815668
# local fitness 0.7868345984993204
# global running time 23.19476294517517
# local running time 0.1362922251224518
# memory usage 464
#
#  >> ocp rank-10 n_iter-1
# ||A-B||: 194318.2259938806
# global fitness 0.7823009798217401
# local fitness 0.7943231550632553
# global running time 24.26471471786499
# local running time 0.15958049297332763
# memory usage 1760
#
#  >> fcp rank-10 n_iter-1
# global fitness 0.8231884399687643
# global running time 369.5767982006073
# memory usage 377856248
# -----------------------------------
# making init decomposition result: 23.1671359539032
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 117392.58453465586
# split: 4 refine: 8
# global fitness 0.8684824828001829
# local fitness 0.8819366640217845
# global running time 122.96969723701477
# local running time 0.4062858521938324
# memory usage 584
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 172398.74846752296
# global fitness 0.8068578568511635
# local fitness 0.8060405360283736
# global running time 42.79579949378967
# local running time 0.31574985980987547
# memory usage 464
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 188486.4744974743
# global fitness 0.7888344204200025
# local fitness 0.8121772393887828
# global running time 42.7256076335907
# local running time 0.30964034199714663
# memory usage 4160
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.8486607188920758
# global running time 737.7688868045807
# memory usage 377856248
# -----------------------------------
# making init decomposition result: 30.745486974716187
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 123337.20392653476
# split: 3 refine: 10
# global fitness 0.8618225937942723
# local fitness 0.8864644767472345
# global running time 158.88985872268677
# local running time 0.6212259411811829
# memory usage 552
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 153196.50640476652
# global fitness 0.8283705546997919
# local fitness 0.8252325288814205
# global running time 57.991650342941284
# local running time 0.5024600923061371
# memory usage 464
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 170325.30770094114
# global fitness 0.8091807785481573
# local fitness 0.8337187099613522
# global running time 56.73201656341553
# local running time 0.4671776294708252
# memory usage 8160
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.8614821048119443
# global running time 1120.186862230301
# memory usage 377856248
# -----------------------------------
# making init decomposition result: 43.396403789520264
#
#  >> dao rank-40 n_iter-1
# ||A-B||: 98321.5225657634
# split: 4 refine: 10
# global fitness 0.8898482166789881
# local fitness 0.9033070408680766
# global running time 263.8576328754425
# local running time 0.7682994961738586
# memory usage 584
#
#  >> dtd rank-40 n_iter-1
# ||A-B||: 140316.1251939566
# global fitness 0.8428007315644371
# local fitness 0.8382653417821686
# global running time 76.0490574836731
# local running time 0.6350912988185883
# memory usage 464
#
#  >> ocp rank-40 n_iter-1
# ||A-B||: 154834.876357338
# global fitness 0.8265350524892296
# local fitness 0.8445242959655006
# global running time 72.81257486343384
# local running time 0.5623719215393066
# memory usage 13760
#
#  >> fcp rank-40 n_iter-1
# global fitness 0.8721753432429995
# global running time 1503.2900714874268
# memory usage 377856248
# -----------------------------------
# making init decomposition result: 81.4874496459961
#
#  >> dao rank-50 n_iter-1
# ||A-B||: 113821.50951732004
# split: 2 refine: 10
# global fitness 0.8724832373783025
# local fitness 0.893044341380582
# global running time 271.33610105514526
# local running time 1.0620250463485719
# memory usage 552
#
#  >> dtd rank-50 n_iter-1
# ||A-B||: 141331.87342055174
# global fitness 0.8416627662884237
# local fitness 0.8404105046208874
# global running time 121.68887948989868
# local running time 0.8385367810726165
# memory usage 464
#
#  >> ocp rank-50 n_iter-1
# ||A-B||: 163306.30767423773
# global fitness 0.8170443200179762
# local fitness 0.8470553649984429
# global running time 116.1120069026947
# local running time 0.6899158596992493
# memory usage 20960
#
#  >> fcp rank-50 n_iter-1
# global fitness 0.8809003560144568
# global running time 1857.6027345657349
# memory usage 377856248

# %%
datasets = ('video-10', 'video-20', 'video-30', 'video-40', 'video-50')
plot_global(datasets, 'E1_video')
plot_local(datasets, 'E1_video')

# %%
# stock
(n_iter, ul, ll) = (1, 6, 5)
tensor_stream = create_tensor_stream(stock2_tensor, start_to_stream=5, batch_sizes=np.full((1028), 3, dtype=int))
results['stock-10'] = online_tensor_decomposition('stock', stock2_tensor, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock-15'] = online_tensor_decomposition('stock', stock2_tensor, tensor_stream, rank=15, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock-20'] = online_tensor_decomposition('stock', stock2_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock-25'] = online_tensor_decomposition('stock', stock2_tensor, tensor_stream, rank=25, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['stock-30'] = online_tensor_decomposition('stock', stock2_tensor, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# /home/lucetre/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# -----------------------------------
# making init decomposition result: 0.3521080017089844
#
#  >> dao rank-10 n_iter-1
# ||A-B||: 31.56705510721439
# split: 23 refine: 1
# global fitness 0.976013615621489
# local fitness 0.9716090471188815
# global running time 19.142903327941895
# local running time 0.006187610821037441
# memory usage 672
#
#  >> dtd rank-10 n_iter-1
# ||A-B||: 32.19295757919115
# global fitness 0.9755380205041966
# local fitness 0.9707181070330326
# global running time 7.896629333496094
# local running time 0.006133253936173851
# memory usage 424
#
#  >> ocp rank-10 n_iter-1
# ||A-B||: 32.302264775991475
# global fitness 0.9754549628851413
# local fitness 0.9707167596694832
# global running time 4.421254396438599
# local running time 0.0026640989437177486
# memory usage 1696
#
#  >> fcp rank-10 n_iter-1
# global fitness 0.9761081625198569
# global running time 26.059345722198486
# memory usage 8416
# -----------------------------------
# making init decomposition result: 0.708427906036377
#
#  >> dao rank-15 n_iter-1
# ||A-B||: 30.798351775639734
# split: 23 refine: 1
# global fitness 0.9765977186846847
# local fitness 0.9714176809504936
# global running time 13.464184761047363
# local running time 0.008389892049336711
# memory usage 672
#
#  >> dtd rank-15 n_iter-1
# ||A-B||: 31.389504543669318
# global fitness 0.9761485283033768
# local fitness 0.9704305884950526
# global running time 10.197710752487183
# local running time 0.007952039111912947
# memory usage 424
#
#  >> ocp rank-15 n_iter-1
# ||A-B||: 31.571143036391586
# global fitness 0.9760105093881003
# local fitness 0.9704340012309235
# global running time 3.856236457824707
# local running time 0.001968515754209882
# memory usage 2696
#
#  >> fcp rank-15 n_iter-1
# global fitness 0.9771396872726076
# global running time 38.509334564208984
# memory usage 8416
# -----------------------------------
# making init decomposition result: 0.9494302272796631
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 29.69812835256206
# split: 23 refine: 1
# global fitness 0.9774337289440691
# local fitness 0.9712541413111829
# global running time 20.68751573562622
# local running time 0.01310156616255467
# memory usage 672
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 30.35987457511313
# global fitness 0.9769308977740019
# local fitness 0.9703043847802101
# global running time 12.000659704208374
# local running time 0.009533218836506053
# memory usage 424
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 30.59820587485098
# global fitness 0.9767498005463534
# local fitness 0.9703247956140365
# global running time 4.103179931640625
# local running time 0.0019089929788492998
# memory usage 4096
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.9778855257573267
# global running time 50.43993854522705
# memory usage 8416
# -----------------------------------
# making init decomposition result: 0.1807243824005127
#
#  >> dao rank-25 n_iter-1
# ||A-B||: 29.04166968789946
# split: 23 refine: 1
# global fitness 0.9779325423368839
# local fitness 0.9710457043629427
# global running time 20.64859890937805
# local running time 0.013210093232908138
# memory usage 672
#
#  >> dtd rank-25 n_iter-1
# ||A-B||: 29.70961126124956
# global fitness 0.9774250035985902
# local fitness 0.9701033833833769
# global running time 14.630598783493042
# local running time 0.01278527144792015
# memory usage 424
#
#  >> ocp rank-25 n_iter-1
# ||A-B||: 30.04398298394199
# global fitness 0.9771709295762094
# local fitness 0.9701495057636818
# global running time 4.7943642139434814
# local running time 0.0033850273269623635
# memory usage 5896
#
#  >> fcp rank-25 n_iter-1
# global fitness 0.9784836295030834
# global running time 64.77799820899963
# memory usage 8416
# -----------------------------------
# making init decomposition result: 0.09477853775024414
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 28.53330802109731
# split: 23 refine: 1
# global fitness 0.978318823486703
# local fitness 0.9709105403585097
# global running time 29.067920207977295
# local running time 0.019274561553613685
# memory usage 672
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 29.212575838385273
# global fitness 0.9778026784454223
# local fitness 0.9699877161978406
# global running time 21.276407718658447
# local running time 0.01934894722259462
# memory usage 424
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 29.529626966597284
# global fitness 0.9775617655632068
# local fitness 0.9699863330559259
# global running time 5.057245254516602
# local running time 0.003703580988056465
# memory usage 8096
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.9790825506977794
# global running time 78.52231502532959
# memory usage 8416

# %%
datasets = ('stock-10', 'stock-15', 'stock-20', 'stock-25', 'stock-30')
plot_global(datasets, 'E1_stock')
plot_local(datasets, 'E1_stock')

# %%
# hall
(n_iter, ul, ll) = (1, 0.5, 0.1)
tensor_stream = create_tensor_stream(hall1_tensor, start_to_stream=10, batch_sizes=np.full((19), 10, dtype=int))
results['hall-10'] = online_tensor_decomposition('hall', hall1_tensor, tensor_stream, rank=15, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall-15'] = online_tensor_decomposition('hall', hall1_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall-20'] = online_tensor_decomposition('hall', hall1_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall-25'] = online_tensor_decomposition('hall', hall1_tensor, tensor_stream, rank=25, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['hall-30'] = online_tensor_decomposition('hall', hall1_tensor, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 1.3904378414154053
#
#  >> dao rank-15 n_iter-1
# ||A-B||: 47914.83089658315
# split: 4 refine: 0
# global fitness 0.8645608796533149
# local fitness 0.8710250904257262
# global running time 7.6090617179870605
# local running time 0.027388233887521846
# memory usage 456
#
#  >> dtd rank-15 n_iter-1
# ||A-B||: 50890.34180686543
# global fitness 0.8561501105296503
# local fitness 0.8579132183609013
# global running time 1.8929588794708252
# local running time 0.02316099718997353
# memory usage 424
#
#  >> ocp rank-15 n_iter-1
# ||A-B||: 51380.800494505704
# global fitness 0.854763748687661
# local fitness 0.8601154762493014
# global running time 1.5858478546142578
# local running time 0.006890146355879934
# memory usage 2696
#
#  >> fcp rank-15 n_iter-1
# global fitness 0.8654084643443207
# global running time 32.240145683288574
# memory usage 20275432
# -----------------------------------
# making init decomposition result: 2.0192713737487793
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 44708.3243725392
# split: 4 refine: 2
# global fitness 0.8736245957277755
# local fitness 0.8817648404379044
# global running time 10.40272855758667
# local running time 0.03967828499643426
# memory usage 536
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 48224.61226913778
# global fitness 0.8636852318462894
# local fitness 0.8650353316828927
# global running time 2.8171093463897705
# local running time 0.03912169054934853
# memory usage 424
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 49032.91914443076
# global fitness 0.861400420022657
# local fitness 0.8675219572245474
# global running time 2.253180503845215
# local running time 0.010054186770790502
# memory usage 4096
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.8761785678287108
# global running time 44.976134061813354
# memory usage 20275432
# -----------------------------------
# making init decomposition result: 2.080848455429077
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 44764.84402350352
# split: 4 refine: 1
# global fitness 0.8734648336736125
# local fitness 0.8810327386647392
# global running time 10.734913110733032
# local running time 0.05089402198791504
# memory usage 536
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 47876.63345939548
# global fitness 0.8646688509681539
# local fitness 0.8663860262255745
# global running time 3.1557610034942627
# local running time 0.05192597288834421
# memory usage 424
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 48490.66555532205
# global fitness 0.8629331886402116
# local fitness 0.8693908717745331
# global running time 2.3984673023223877
# local running time 0.013679905941611841
# memory usage 4096
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.8763543003499585
# global running time 40.13906764984131
# memory usage 20275432
# -----------------------------------
# making init decomposition result: 3.2160565853118896
#
#  >> dao rank-25 n_iter-1
# ||A-B||: 41599.14888375507
# split: 7 refine: 4
# global fitness 0.88241318968344
# local fitness 0.8965126683148129
# global running time 18.96110200881958
# local running time 0.06376673045911287
# memory usage 536
#
#  >> dtd rank-25 n_iter-1
# ||A-B||: 45908.998239523215
# global fitness 0.8702306943130224
# local fitness 0.8711620748822055
# global running time 4.39587926864624
# local running time 0.05927341862728721
# memory usage 424
#
#  >> ocp rank-25 n_iter-1
# ||A-B||: 46826.22954821515
# global fitness 0.8676379897311821
# local fitness 0.8737224363164693
# global running time 3.4388535022735596
# local running time 0.00943530233282792
# memory usage 5896
#
#  >> fcp rank-25 n_iter-1
# global fitness 0.8850278975507911
# global running time 50.030431509017944
# memory usage 20275432
# -----------------------------------
# making init decomposition result: 2.6405930519104004
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 39287.387680485845
# split: 8 refine: 4
# global fitness 0.8889477615052244
# local fitness 0.9038142226224605
# global running time 24.73479461669922
# local running time 0.07754447585658024
# memory usage 600
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 43802.83047251223
# global fitness 0.8761841226008565
# local fitness 0.8763033597852002
# global running time 3.877523183822632
# local running time 0.061898645601774514
# memory usage 424
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 44838.558535081225
# global fitness 0.8732564675285578
# local fitness 0.8789633752662005
# global running time 2.9145660400390625
# local running time 0.011826766164679276
# memory usage 8096
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.8912358075738221
# global running time 54.28375196456909
# memory usage 20275432

# %%
datasets = ('hall-10', 'hall-15', 'hall-20', 'hall-25', 'hall-30')
plot_global(datasets, 'E1_hall')
plot_local(datasets, 'E1_hall')

# %%
# korea air-quality
(n_iter, ul, ll) = (1, 2, 1.3)
tensor_stream = create_tensor_stream(korea_tensor, start_to_stream=79, batch_sizes=np.full((94), 100, dtype=int))
results['korea-10'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=10, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['korea-15'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=15, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['korea-20'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['korea-25'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=25, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
results['korea-30'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# /home/lucetre/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# -----------------------------------
# making init decomposition result: 1.9017038345336914
#
#  >> dao rank-10 n_iter-1
# ||A-B||: 19586.677629810532
# split: 7 refine: 1
# global fitness 0.8026374672526058
# local fitness 0.8024567758848932
# global running time 22.71766948699951
# local running time 0.02569765993889342
# memory usage 536
#
#  >> dtd rank-10 n_iter-1
# ||A-B||: 21544.112585599596
# global fitness 0.7829136361943545
# local fitness 0.7894373181042726
# global running time 11.132720947265625
# local running time 0.026690186338221775
# memory usage 424
#
#  >> ocp rank-10 n_iter-1
# ||A-B||: 21937.41411503054
# global fitness 0.7789505860309223
# local fitness 0.7861505734816597
# global running time 9.113791465759277
# local running time 0.009320109448534376
# memory usage 1696
#
#  >> fcp rank-10 n_iter-1
# global fitness 0.790791113117474
# global running time 199.51153898239136
# memory usage 944
# -----------------------------------
# making init decomposition result: 2.5461320877075195
#
#  >> dao rank-15 n_iter-1
# ||A-B||: 18700.901480008088
# split: 5 refine: 4
# global fitness 0.8115628719422798
# local fitness 0.8088854217809315
# global running time 22.036972284317017
# local running time 0.032441146830294997
# memory usage 536
#
#  >> dtd rank-15 n_iter-1
# ||A-B||: 20227.48322579425
# global fitness 0.7961804755252511
# local fitness 0.798671992769592
# global running time 11.716506481170654
# local running time 0.031125626665480594
# memory usage 424
#
#  >> ocp rank-15 n_iter-1
# ||A-B||: 20534.903657603903
# global fitness 0.793082794734921
# local fitness 0.7963400041247444
# global running time 9.701826095581055
# local running time 0.0111780749990585
# memory usage 2696
#
#  >> fcp rank-15 n_iter-1
# global fitness 0.8053121179245069
# global running time 299.0361421108246
# memory usage 944
# -----------------------------------
# making init decomposition result: 2.7563860416412354
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 17837.730371605838
# split: 5 refine: 5
# global fitness 0.8202604999611003
# local fitness 0.8172940037091443
# global running time 26.810022115707397
# local running time 0.04078721239211711
# memory usage 536
#
#  >> dtd rank-20 n_iter-1
# ||A-B||: 19357.63006333933
# global fitness 0.804945434366415
# local fitness 0.8044670388660038
# global running time 13.285565376281738
# local running time 0.03933468017172306
# memory usage 424
#
#  >> ocp rank-20 n_iter-1
# ||A-B||: 19529.783259960288
# global fitness 0.803210755747211
# local fitness 0.8031871664987822
# global running time 10.433692216873169
# local running time 0.012639126879103641
# memory usage 4096
#
#  >> fcp rank-20 n_iter-1
# global fitness 0.8150072718279798
# global running time 395.0749521255493
# memory usage 944
# -----------------------------------
# making init decomposition result: 3.2606759071350098
#
#  >> dao rank-25 n_iter-1
# ||A-B||: 16678.56866294454
# split: 9 refine: 5
# global fitness 0.831940637604097
# local fitness 0.8269477673094393
# global running time 43.79110813140869
# local running time 0.048565491716912455
# memory usage 600
#
#  >> dtd rank-25 n_iter-1
# ||A-B||: 18615.064204495604
# global fitness 0.8124277997477743
# local fitness 0.8101659413442475
# global running time 14.722556114196777
# local running time 0.05325364559254748
# memory usage 424
#
#  >> ocp rank-25 n_iter-1
# ||A-B||: 18828.321312308948
# global fitness 0.8102789430748913
# local fitness 0.8077031946219728
# global running time 10.834378719329834
# local running time 0.013031338123565024
# memory usage 5896
#
#  >> fcp rank-25 n_iter-1
# global fitness 0.8222856444817838
# global running time 492.00512075424194
# memory usage 944
# -----------------------------------
# making init decomposition result: 4.5302207469940186
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 11380.787600958103
# split: 47 refine: 2
# global fitness 0.8853230186335098
# local fitness 0.8837457977322309
# global running time 243.8758692741394
# local running time 0.03556670280213051
# memory usage 936
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 17996.224682781027
# global fitness 0.8186634532709572
# local fitness 0.8136463490756647
# global running time 15.672938823699951
# local running time 0.05730321559500187
# memory usage 424
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 18403.974998524223
# global fitness 0.8145548118482207
# local fitness 0.8103230177231704
# global running time 11.701217651367188
# local running time 0.011700594678838203
# memory usage 8096
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.8289441447133559
# global running time 590.7631964683533
# memory usage 944

# %%
datasets = ('korea-10', 'korea-15', 'korea-20', 'korea-25', 'korea-30')
plot_global(datasets, 'E1_korea')
plot_local(datasets, 'E1_korea')

# %% [markdown]
# ---
# # Experiment #2

# %%
plot_mem(('synthetic-30', 'video-30', 'stock-20', 'hall-20', 'korea-20'), 'E2')

# %% [markdown]
# ---
# # Experiment #5

# %%
def plot_E5(dataset):
    verbose_list = results[dataset]['dao'][5]
    split_points, refine_points = results[dataset]['dao'][6]
    color = 'tab:red'
    
    fig, ax1 = plt.subplots()
    #         plt.xticks(rotation=45)
    ax1.set_ylabel('Local Error Norm', color=color, fontsize=12)
    ax1.set_xlabel('# of Income Slices', fontsize=12)
    #         ax1.xaxis.set_label_position('top')
    
    for p in refine_points:
        ax1.axvline(p,  label='line: {}'.format(p), c='lightgray', linewidth=2, linestyle='--')
    for p in split_points:
        ax1.axvline(p,  label='line: {}'.format(p), c='lightgray', linewidth=2, linestyle='-')
    
    ax1.plot(verbose_list[:,0], verbose_list[:,2], linewidth=1, marker="2", color=color)
    
    color = 'tab:blue'
    ax2 = ax1.twinx()
    ax2.set_ylabel('Local Running Time (s)', color=color,  rotation=270, fontsize=12, labelpad=15)
    ax2.plot(verbose_list[:,0], verbose_list[:,1], linewidth=0.5, marker="2", color=color)
    fig.tight_layout()

    plt.savefig('plots/E5_{}.pdf'.format(dataset), bbox_inches='tight', pad_inches=0)

# %%
def plot_E5_error(dataset):
    
    markers = ("+", "x", "1")
    colors = ('dodgerblue','mediumseagreen', 'hotpink')
    libs = ("dao", "dtd", "ocp")
    fig = plt.figure(figsize = (4, 4), dpi = 150,) 
    fig, ax1 = plt.subplots()
    ax1.set_ylabel('Local Error Norm', fontsize=12)
    ax1.set_xlabel('Number of Incomed Slices', fontsize=12)
    #         ax1.xaxis.set_label_position('top')
    
    
    split_points, refine_points = results[dataset]['dao'][6]
    for p in refine_points:
        ax1.axvline(p,  label='line: {}'.format(p), c='lightgray', linewidth=2, linestyle='--')
    for p in split_points:
        ax1.axvline(p,  label='line: {}'.format(p), c='lightgray', linewidth=2, linestyle='-')
    
    for color, marker, lib in zip(colors, markers, libs):
        verbose_list = results[dataset][lib][5]
        ax1.plot(verbose_list[:,0], verbose_list[:,2], linewidth=1, marker=marker, color=color)
    plt.savefig('plots/E5_{}_error.pdf'.format(dataset), bbox_inches='tight', pad_inches=0)

def plot_E5_rt(dataset):
    markers = ("+", "x", "1")
    colors = ('dodgerblue','mediumseagreen', 'hotpink')
    libs = ("dao", "dtd", "ocp")
    fig = plt.figure(figsize = (4, 4), dpi = 150,) 
    fig, ax1 = plt.subplots()
    ¶
    ax1.set_yscale('log')
    ax1.set_ylabel('Local Running Time', fontsize=12)
    ax1.set_xlabel('Number of Incomed Slices', fontsize=12)
    #         ax1.xaxis.set_label_position('top')
    
    
    split_points, refine_points = results[dataset]['dao'][6]
    for p in refine_points:
        ax1.axvline(p,  label='line: {}'.format(p), c='lightgray', linewidth=2, linestyle='--')
    for p in split_points:
        ax1.axvline(p,  label='line: {}'.format(p), c='lightgray', linewidth=2, linestyle='-')
    
    for color, marker, lib in zip(colors, markers, libs):
        verbose_list = results[dataset][lib][5]
        ax1.plot(verbose_list[:,0], verbose_list[:,1], linewidth=1, marker=marker, color=color)
        plt.savefig('plots/E5_{}_rt.pdf'.format(dataset), bbox_inches='tight', pad_inches=0)

# %%
# plot_E5_error('video-30')
# plot_E5_rt('video-30')
for dataset in ('video-30', 'stock-20', 'hall-20', 'korea-20'):
    plot_E5_error(dataset)
    plot_E5_rt(dataset)

# %% [markdown]
# ---
# # Experiment #3

# %%
results['korea--'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=-1, ll=-1, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 2.5740034580230713
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 19353.212324869022
# split: 0 refine: 0
# global fitness 0.8049899491161848
# local fitness 0.807301287175918
# global running time 12.721801519393921
# local running time 0.04343572575995262
# memory usage 424

# %%
# korea air-quality
tensor_stream = create_tensor_stream(korea_tensor, start_to_stream=79, batch_sizes=np.full((94), 100, dtype=int))
results['korea-split-1.0'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=1.0, ll=-1, verbose=False) # 65
results['korea-split-1.2'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=1.2, ll=-1, verbose=False) # 57
results['korea-split-1.4'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=1.4, ll=-1, verbose=False) # 45
results['korea-split-1.6'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=1.6, ll=-1, verbose=False) # 36
results['korea-split-1.8'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=1.8, ll=-1, verbose=False) # 5
# Out:
# -----------------------------------
# making init decomposition result: 2.768756628036499
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 13553.896696550253
# split: 57 refine: 0
# global fitness 0.8634259760033854
# local fitness 0.8745179307559414
# global running time 184.3911006450653
# local running time 0.01589446118537416
# memory usage 856
# -----------------------------------
# making init decomposition result: 2.999936819076538
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 14171.3751455951
# split: 45 refine: 0
# global fitness 0.857204037146591
# local fitness 0.864429339300147
# global running time 147.55927538871765
# local running time 0.024061928404138445
# memory usage 760
# -----------------------------------
# making init decomposition result: 2.7193710803985596
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 14618.059362050037
# split: 36 refine: 0
# global fitness 0.8527030834900272
# local fitness 0.8572987233155653
# global running time 125.2348403930664
# local running time 0.022461454919044006
# memory usage 760
# -----------------------------------
# making init decomposition result: 2.4552929401397705
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 17694.487090106413
# split: 5 refine: 0
# global fitness 0.821703871694178
# local fitness 0.8147468669316307
# global running time 24.04918670654297
# local running time 0.03068742346256337
# memory usage 456

# %%
# korea air-quality
tensor_stream = create_tensor_stream(korea_tensor, start_to_stream=79, batch_sizes=np.full((94), 100, dtype=int))
results['korea-refine-1.4'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=-1, ll=1.4, verbose=False) # 15
results['korea-refine-1.6'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=-1, ll=1.6, verbose=False) # 14
results['korea-refine-1.8'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=-1, ll=1.8, verbose=False) # 12
results['korea-refine-2.0'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=-1, ll=2.0, verbose=False) # 8
results['korea-refine-2.2'] = online_tensor_decomposition('korea', korea_tensor, tensor_stream, rank=20, methods=['dao'], n_iter=n_iter, ul=-1, ll=2.2, verbose=False) # 6
# Out:
# /home/lucetre/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# -----------------------------------
# making init decomposition result: 2.936098575592041
#
#  >> dao rank-20 n_iter-1
# ||A-B||: 19229.81411563783
# split: 0 refine: 6
# global fitness 0.8062333546375631
# local fitness 0.8070007458675443
# global running time 13.253572463989258
# local running time 0.0464605524184856
# memory usage 504

# %%
for dataset in ('korea-split-1.0', 'korea-split-1.2', 'korea-split-1.4', 'korea-split-1.6', 'korea-split-1.8'):
    plot_E5(dataset)
for dataset in ('korea-refine-1.4', 'korea-refine-1.6', 'korea-refine-1.8', 'korea-refine-2.0', 'korea-refine-2.2'):
    plot_E5(dataset)

# %%
rows = []
for dataset in ('korea-split-1.0', 'korea-split-1.2', 'korea-split-1.4', 'korea-split-1.6', 'korea-split-1.8'):
    row = dataset.split('-')
    row.append('-')
    verbose_list = results[dataset]['dao'][5]
    split_points, refine_points = results[dataset]['dao'][6]
    row.append(len(split_points))
    row += results[dataset]['dao'][:5]
    rows.append(row)
    
for dataset in ('korea-refine-1.4', 'korea-refine-1.6', 'korea-refine-1.8', 'korea-refine-2.0', 'korea-refine-2.2'):
    row = dataset.split('-')[:-1]
    row.append('-')
    row.append(dataset.split('-')[-1])
    verbose_list = results[dataset]['dao'][5]
    split_points, refine_points = results[dataset]['dao'][6]
    row.append(len(refine_points))
    row += results[dataset]['dao'][:5]
    rows.append(row)
    
dataset = 'korea--'
row = dataset.split('-')[:1]
row += ['-'] * 3
verbose_list = results[dataset]['dao'][5]
split_points, refine_points = results[dataset]['dao'][6]
row.append(len(refine_points))
row += results[dataset]['dao'][:5]
rows.append(row)
    
df = pd.DataFrame(rows, columns=['dataset', 'process', 'ul', 'll', 'points-#', 'global-fit', 'local-fit', 'global-rt', 'local-rt', 'mem'])
df
# Out:
#    dataset process   ul   ll  points-#  global-fit  local-fit   global-rt  \
# 0    korea   split  1.0    -        65    0.875591   0.883524  211.415973
# 1    korea   split  1.2    -        57    0.863426   0.874518  184.391101
# 2    korea   split  1.4    -        45    0.857204   0.864429  147.559275
# 3    korea   split  1.6    -        36    0.852703   0.857299  125.234840
# 4    korea   split  1.8    -         5    0.821704   0.814747   24.049187
# 5    korea  refine    -  1.4        15    0.807248   0.808710   12.960902
# 6    korea  refine    -  1.6        14    0.806959   0.808329   12.481139
# 7    korea  refine    -  1.8        12    0.806698   0.808163   12.561460
# 8    korea  refine    -  2.0         8    0.806506   0.807232   13.393017
# 9    korea  refine    -  2.2         6    0.806233   0.807001   13.253572
# 10   korea       -    -    -         0    0.804990   0.807301   12.721802
#
#     local-rt  mem
# 0   0.011492  968
# 1   0.015894  856
# 2   0.024062  760
# 3   0.022461  760
# 4   0.030687  456
# 5   0.047423  504
# 6   0.044514  504
# 7   0.042302  504
# 8   0.053907  504
# 9   0.046461  504
# 10  0.043436  424

# %% [markdown]
# ---
# # Experiment #4

# %%
# hall
(n_iter, ul, ll) = (1, 0.5, 0.1)
tensor_stream = create_tensor_stream(hall1_tensor, start_to_stream=10, batch_sizes=np.full((19), 10, dtype=int))
results['hall'] = online_tensor_decomposition('hall', hall1_tensor, tensor_stream, rank=100, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 9.160423517227173
#
#  >> dao rank-100 n_iter-1
# ||A-B||: 16080.812899047627
# split: 18 refine: 0
# global fitness 0.9545449475088944
# local fitness 0.9615965709744833
# global running time 192.9630901813507
# local running time 0.028704191509046052
# memory usage 592
#
#  >> dtd rank-100 n_iter-1
# ||A-B||: 32517.506145023777
# global fitness 0.908083940906405
# local fitness 0.9024140471133417
# global running time 14.058639764785767
# local running time 0.2551487746991609
# memory usage 424
#
#  >> ocp rank-100 n_iter-1
# ||A-B||: 34648.592200826635
# global fitness 0.9020600769924533
# local fitness 0.9049374823923566
# global running time 10.379172563552856
# local running time 0.06046026631405479
# memory usage 80896
#
#  >> fcp rank-100 n_iter-1
# global fitness 0.9246706261901234
# global running time 177.90529322624207
# memory usage 20275432

# %%
frame = results['hall']['dao'][6][0][10]*10
for lib in ("dao", "dtd", "ocp", 'fcp'):
    make_video(results['hall'][lib][-1], f'plots/E4-hall-{lib}.avi', False)
    imwrite(f'plots/E4-hall-{lib}-{frame}.jpg', results['hall'][lib][-1][frame])
make_video(hall1_tensor, 'plots/E4-hall-org.avi', False)
imwrite(f'plots/E4-hall-org-{frame}.jpg', hall1_tensor[frame])
# Out:
# created plots/E4-hall-dao.avi 0.12594866752624512
# created plots/E4-hall-dtd.avi 0.0802299976348877
# created plots/E4-hall-ocp.avi 0.07880616188049316
# created plots/E4-hall-fcp.avi 0.08109521865844727
# created plots/E4-hall-org.avi 0.08361315727233887
# True

# %%
# video
(n_iter, ul, ll) = (1, 6, 2)
tensor_stream = create_tensor_stream(sample_video, start_to_stream=5, batch_sizes=np.full((40), 5, dtype=int))
results['video'] = online_tensor_decomposition('video', sample_video, tensor_stream, rank=30, n_iter=n_iter, ul=ul, ll=ll, verbose=False)
# Out:
# -----------------------------------
# making init decomposition result: 22.973731756210327
#
#  >> dao rank-30 n_iter-1
# ||A-B||: 111858.7719198651
# split: 3 refine: 8
# global fitness 0.8746821358586047
# local fitness 0.8772962957132459
# global running time 112.28189468383789
# local running time 0.4906603157520294
# memory usage 552
#
#  >> dtd rank-30 n_iter-1
# ||A-B||: 154844.18239490307
# global fitness 0.8265246267288601
# local fitness 0.8264623609028907
# global running time 43.92041492462158
# local running time 0.36424521803855897
# memory usage 464
#
#  >> ocp rank-30 n_iter-1
# ||A-B||: 168805.17123939507
# global fitness 0.8108838211553199
# local fitness 0.8328352781986471
# global running time 45.600608825683594
# local running time 0.40389721393585204
# memory usage 8160
#
#  >> fcp rank-30 n_iter-1
# global fitness 0.8631681036649699
# global running time 1057.3588509559631
# memory usage 377856248

# %%
frame = results['video']['dao'][6][0][1]*5
for lib in ("dao", "dtd", "ocp", 'fcp'):
    make_video(results['video'][lib][-1], f'plots/E4-video-{lib}.avi')
    imwrite(f'plots/E4-video-{lib}-{frame}.jpg', results['video'][lib][-1][frame])
make_video(sample_video, 'plots/E4-video-org.avi')
imwrite(f'plots/E4-video-org-{frame}.jpg', sample_video[frame])
# Out:
# created plots/E4-video-dao.avi 0.2626831531524658
# created plots/E4-video-dtd.avi 0.2940220832824707
# created plots/E4-video-ocp.avi 0.2860386371612549
# created plots/E4-video-fcp.avi 0.26885509490966797
# created plots/E4-video-org.avi 0.2976257801055908
# True

# %% [markdown]
# ---
# ## batch size

# %%
(n_iter, ul, ll) = (1, 2, 1.3)
tensor_stream = create_tensor_stream(korea_tensor, start_to_stream=-5)
tensor_stream = create_tensor_stream(korea_tensor, start_to_stream=-10)
tensor_stream = create_tensor_stream(korea_tensor, start_to_stream=-50)
# tensor_stream = create_tensor_stream(korea_tensor, start_to_stream=-100)
